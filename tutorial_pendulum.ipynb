# %% [markdown]
# <a href="https://colab.research.google.com/github/alinjar1996/tutorial_cem/blob/main/tutorial_pendulum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update
# !sudo apt-get install python3.10 python3.10-venv python3.10-distutils

# %%
# !python3.10 -m venv py310_env

# %%
# !py310_env/bin/python -m ensurepip
# !py310_env/bin/pip install pip==22.0.2

# %%
# !py310_env/bin/python --version
# !py310_env/bin/pip --version

# %%
# !git clone https://github.com/alinjar1996/sampling_based_general.git -b issue_2_pendulum

# %%
# %cd /content/sampling_based_general
# !git pull

# %%
# !ls /content
# !/content/py310_env/bin/pip install -r requirements.txt

# %%
# %cd /content/sampling_based_general/real_demo

# !git clone https://github.com/AKS-Lab-Univertsity-of-Tartu/math_utils_aks_lab.git math_utils

# %%
# %cd /content/sampling_based_general
# Out:
# /content/sampling_based_general

# %%
# !apt-get update
# !apt-get install -y libgl1-mesa-dev libegl1-mesa-dev

# %%
# !/content/py310_env/bin/pip install imageio[ffmpeg]

# %%
# !python3 -u real_demo/pendulum_demo_pyt_colab.py
# !/content/py310_env/bin/python3.10 real_demo/pendulum_demo_pyt_colab.py --num_batch 500 --maxiter_cem 1 --steps 100
# !/content/py310_env/bin/python3.10 \
    real_demo/pendulum_demo_pyt_colab.py \
    --num_batch 500 \
    --maxiter_cem 10 \
    --steps 250 \
    --timestep 0.1 \
    --num_steps 30
# Out:
# \Torque-controlled joints:
#   0: 'pendulum_joint' -> controlled: True
#
#  Default backend: gpu
#  Timestep: 0.1
#  CEM Iter: 10
#  Projection Iter: 1
#  Number of batches: 500
#  Number of steps per trajectory: 30
#  Time per trajectory: 3.0
#  Number of variables: 11
#  Number of Total constraints: 180
#
# | Step 0
#
# | Total time: 11.9s
# | Step time: 11934.7ms
# | Total Cost (Across Horizon): 502.60
# | Cost Theta (Across Horizon): 502.31
# | Cost ThetaDot (Across Horizon): 1.00
# | Cost Control (Across Horizon): 0.01
#
# | Step 1
#
# | Total time: 17.4s
# | Step time: 5401.3ms
# | Total Cost (Across Horizon): 467.96
# | Cost Theta (Across Horizon): 467.23
# | Cost ThetaDot (Across Horizon): 0.93
# | Cost Control (Across Horizon): 0.01
#
# | Step 2
#
# | Total time: 17.9s
# | Step time: 490.7ms
# | Total Cost (Across Horizon): 461.45
# | Cost Theta (Across Horizon): 460.60
# | Cost ThetaDot (Across Horizon): 0.92
# | Cost Control (Across Horizon): 0.02
#
# | Step 3
#
# | Total time: 18.4s
# | Step time: 501.3ms
# | Total Cost (Across Horizon): 462.88
# | Cost Theta (Across Horizon): 461.96
# | Cost ThetaDot (Across Horizon): 0.92
# | Cost Control (Across Horizon): 0.02
#
# | Step 4
#
# | Total time: 18.7s
# | Step time: 312.5ms
# | Total Cost (Across Horizon): 463.85
# | Cost Theta (Across Horizon): 462.46
# | Cost ThetaDot (Across Horizon): 0.92
# | Cost Control (Across Horizon): 0.01
#
# | Step 5
#
# | Total time: 19.0s
# | Step time: 327.4ms
# | Total Cost (Across Horizon): 451.59
# | Cost Theta (Across Horizon): 450.05
# | Cost ThetaDot (Across Horizon): 0.90
# | Cost Control (Across Horizon): 0.00
#
# | Step 6
#
# | Total time: 19.3s
# | Step time: 306.6ms
# | Total Cost (Across Horizon): 413.97
# | Cost Theta (Across Horizon): 411.71
# | Cost ThetaDot (Across Horizon): 0.82
# | Cost Control (Across Horizon): 0.01
#
# | Step 7
#
# | Total time: 19.7s
# | Step time: 314.7ms
# | Total Cost (Across Horizon): 368.09
# | Cost Theta (Across Horizon): 364.75
# | Cost ThetaDot (Across Horizon): 0.73
# | Cost Control (Across Horizon): 0.01
#
# | Step 8
#
# | Total time: 20.0s
# | Step time: 326.5ms
# | Total Cost (Across Horizon): 345.71
# | Cost Theta (Across Horizon): 342.02
# | Cost ThetaDot (Across Horizon): 0.68
# | Cost Control (Across Horizon): 0.01
#
# | Step 9
#
# | Total time: 20.3s
# | Step time: 307.4ms
# | Total Cost (Across Horizon): 329.61
# | Cost Theta (Across Horizon): 325.84
# | Cost ThetaDot (Across Horizon): 0.65
# | Cost Control (Across Horizon): 0.01
#
# | Step 10
#
# | Total time: 20.6s
# | Step time: 317.1ms
# | Total Cost (Across Horizon): 308.14
# | Cost Theta (Across Horizon): 304.31
# | Cost ThetaDot (Across Horizon): 0.61
# | Cost Control (Across Horizon): 0.01
#
# | Step 11
#
# | Total time: 21.0s
# | Step time: 325.7ms
# | Total Cost (Across Horizon): 296.32
# | Cost Theta (Across Horizon): 292.98
# | Cost ThetaDot (Across Horizon): 0.59
# | Cost Control (Across Horizon): 0.01
#
# | Step 12
#
# | Total time: 21.3s
# | Step time: 340.6ms
# | Total Cost (Across Horizon): 161.86
# | Cost Theta (Across Horizon): 160.33
# | Cost ThetaDot (Across Horizon): 0.32
# | Cost Control (Across Horizon): 0.01
#
# | Step 13
#
# | Total time: 21.6s
# | Step time: 325.3ms
# | Total Cost (Across Horizon): 141.23
# | Cost Theta (Across Horizon): 139.73
# | Cost ThetaDot (Across Horizon): 0.28
# | Cost Control (Across Horizon): 0.01
#
# | Step 14
#
# | Total time: 22.0s
# | Step time: 344.6ms
# | Total Cost (Across Horizon): 126.26
# | Cost Theta (Across Horizon): 124.76
# | Cost ThetaDot (Across Horizon): 0.25
# | Cost Control (Across Horizon): 0.01
#
# | Step 15
#
# | Total time: 22.3s
# | Step time: 334.0ms
# | Total Cost (Across Horizon): 110.98
# | Cost Theta (Across Horizon): 109.46
# | Cost ThetaDot (Across Horizon): 0.22
# | Cost Control (Across Horizon): 0.01
#
# | Step 16
#
# | Total time: 22.6s
# | Step time: 339.2ms
# | Total Cost (Across Horizon): 96.74
# | Cost Theta (Across Horizon): 95.28
# | Cost ThetaDot (Across Horizon): 0.19
# | Cost Control (Across Horizon): 0.01
#
# | Step 17
#
# | Total time: 23.0s
# | Step time: 347.3ms
# | Total Cost (Across Horizon): 78.34
# | Cost Theta (Across Horizon): 77.04
# | Cost ThetaDot (Across Horizon): 0.15
# | Cost Control (Across Horizon): 0.01
#
# | Step 18
#
# | Total time: 23.3s
# | Step time: 327.2ms
# | Total Cost (Across Horizon): 57.99
# | Cost Theta (Across Horizon): 56.88
# | Cost ThetaDot (Across Horizon): 0.11
# | Cost Control (Across Horizon): 0.01
#
# | Step 19
#
# | Total time: 23.7s
# | Step time: 333.2ms
# | Total Cost (Across Horizon): 38.64
# | Cost Theta (Across Horizon): 37.86
# | Cost ThetaDot (Across Horizon): 0.08
# | Cost Control (Across Horizon): 0.01
#
# | Step 20
#
# | Total time: 24.0s
# | Step time: 343.1ms
# | Total Cost (Across Horizon): 33.47
# | Cost Theta (Across Horizon): 32.98
# | Cost ThetaDot (Across Horizon): 0.07
# | Cost Control (Across Horizon): 0.01
#
# | Step 21
#
# | Total time: 24.4s
# | Step time: 338.6ms
# | Total Cost (Across Horizon): 17.92
# | Cost Theta (Across Horizon): 17.64
# | Cost ThetaDot (Across Horizon): 0.04
# | Cost Control (Across Horizon): 0.01
#
# | Step 22
#
# | Total time: 24.7s
# | Step time: 335.8ms
# | Total Cost (Across Horizon): 12.46
# | Cost Theta (Across Horizon): 12.27
# | Cost ThetaDot (Across Horizon): 0.02
# | Cost Control (Across Horizon): 0.00
#
# | Step 23
#
# | Total time: 25.0s
# | Step time: 348.9ms
# | Total Cost (Across Horizon): 11.63
# | Cost Theta (Across Horizon): 11.53
# | Cost ThetaDot (Across Horizon): 0.02
# | Cost Control (Across Horizon): 0.01
#
# | Step 24
#
# | Total time: 25.4s
# | Step time: 343.6ms
# | Total Cost (Across Horizon): 6.39
# | Cost Theta (Across Horizon): 6.33
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 25
#
# | Total time: 25.7s
# | Step time: 334.3ms
# | Total Cost (Across Horizon): 5.59
# | Cost Theta (Across Horizon): 5.55
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.01
#
# | Step 26
#
# | Total time: 26.1s
# | Step time: 351.9ms
# | Total Cost (Across Horizon): 4.01
# | Cost Theta (Across Horizon): 3.98
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 27
#
# | Total time: 26.4s
# | Step time: 343.5ms
# | Total Cost (Across Horizon): 6.17
# | Cost Theta (Across Horizon): 6.12
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 28
#
# | Total time: 26.8s
# | Step time: 341.6ms
# | Total Cost (Across Horizon): 3.54
# | Cost Theta (Across Horizon): 3.51
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 29
#
# | Total time: 27.1s
# | Step time: 348.6ms
# | Total Cost (Across Horizon): 2.01
# | Cost Theta (Across Horizon): 2.00
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 30
#
# | Total time: 27.5s
# | Step time: 348.6ms
# | Total Cost (Across Horizon): 3.06
# | Cost Theta (Across Horizon): 3.04
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 31
#
# | Total time: 27.8s
# | Step time: 342.3ms
# | Total Cost (Across Horizon): 4.90
# | Cost Theta (Across Horizon): 4.89
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.01
#
# | Step 32
#
# | Total time: 28.2s
# | Step time: 348.0ms
# | Total Cost (Across Horizon): 43.78
# | Cost Theta (Across Horizon): 42.86
# | Cost ThetaDot (Across Horizon): 0.09
# | Cost Control (Across Horizon): 0.00
#
# | Step 33
#
# | Total time: 28.6s
# | Step time: 413.2ms
# | Total Cost (Across Horizon): 1.56
# | Cost Theta (Across Horizon): 1.55
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 34
#
# | Total time: 29.2s
# | Step time: 649.1ms
# | Total Cost (Across Horizon): 4.67
# | Cost Theta (Across Horizon): 4.65
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.01
#
# | Step 35
#
# | Total time: 29.9s
# | Step time: 615.4ms
# | Total Cost (Across Horizon): 2.30
# | Cost Theta (Across Horizon): 2.27
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 36
#
# | Total time: 30.5s
# | Step time: 613.5ms
# | Total Cost (Across Horizon): 2.70
# | Cost Theta (Across Horizon): 2.69
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 37
#
# | Total time: 31.0s
# | Step time: 531.5ms
# | Total Cost (Across Horizon): 2.71
# | Cost Theta (Across Horizon): 2.65
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 38
#
# | Total time: 31.6s
# | Step time: 547.7ms
# | Total Cost (Across Horizon): 2.39
# | Cost Theta (Across Horizon): 2.38
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 39
#
# | Total time: 31.9s
# | Step time: 343.0ms
# | Total Cost (Across Horizon): 1.47
# | Cost Theta (Across Horizon): 1.45
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 40
#
# | Total time: 32.3s
# | Step time: 342.7ms
# | Total Cost (Across Horizon): 15.33
# | Cost Theta (Across Horizon): 14.87
# | Cost ThetaDot (Across Horizon): 0.03
# | Cost Control (Across Horizon): 0.00
#
# | Step 41
#
# | Total time: 32.6s
# | Step time: 365.5ms
# | Total Cost (Across Horizon): 1.51
# | Cost Theta (Across Horizon): 1.50
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 42
#
# | Total time: 33.0s
# | Step time: 350.1ms
# | Total Cost (Across Horizon): 2.83
# | Cost Theta (Across Horizon): 2.82
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 43
#
# | Total time: 33.3s
# | Step time: 374.6ms
# | Total Cost (Across Horizon): 3.13
# | Cost Theta (Across Horizon): 3.08
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 44
#
# | Total time: 33.7s
# | Step time: 355.7ms
# | Total Cost (Across Horizon): 2.74
# | Cost Theta (Across Horizon): 2.70
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 45
#
# | Total time: 34.1s
# | Step time: 345.1ms
# | Total Cost (Across Horizon): 0.91
# | Cost Theta (Across Horizon): 0.90
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 46
#
# | Total time: 34.4s
# | Step time: 354.6ms
# | Total Cost (Across Horizon): 1.57
# | Cost Theta (Across Horizon): 1.53
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 47
#
# | Total time: 34.8s
# | Step time: 358.5ms
# | Total Cost (Across Horizon): 1.60
# | Cost Theta (Across Horizon): 1.59
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 48
#
# | Total time: 35.1s
# | Step time: 347.3ms
# | Total Cost (Across Horizon): 1.36
# | Cost Theta (Across Horizon): 1.35
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 49
#
# | Total time: 35.5s
# | Step time: 340.7ms
# | Total Cost (Across Horizon): 2.25
# | Cost Theta (Across Horizon): 2.23
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 50
#
# | Total time: 35.8s
# | Step time: 366.0ms
# | Total Cost (Across Horizon): 2.97
# | Cost Theta (Across Horizon): 2.95
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 51
#
# | Total time: 36.2s
# | Step time: 342.8ms
# | Total Cost (Across Horizon): 5.00
# | Cost Theta (Across Horizon): 4.91
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 52
#
# | Total time: 36.5s
# | Step time: 339.2ms
# | Total Cost (Across Horizon): 0.84
# | Cost Theta (Across Horizon): 0.83
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 53
#
# | Total time: 36.9s
# | Step time: 353.8ms
# | Total Cost (Across Horizon): 2.06
# | Cost Theta (Across Horizon): 2.01
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 54
#
# | Total time: 37.2s
# | Step time: 335.8ms
# | Total Cost (Across Horizon): 0.92
# | Cost Theta (Across Horizon): 0.90
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 55
#
# | Total time: 37.6s
# | Step time: 332.1ms
# | Total Cost (Across Horizon): 4.98
# | Cost Theta (Across Horizon): 4.89
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 56
#
# | Total time: 37.9s
# | Step time: 347.8ms
# | Total Cost (Across Horizon): 1.16
# | Cost Theta (Across Horizon): 1.15
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 57
#
# | Total time: 38.2s
# | Step time: 345.8ms
# | Total Cost (Across Horizon): 0.83
# | Cost Theta (Across Horizon): 0.82
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 58
#
# | Total time: 38.6s
# | Step time: 343.2ms
# | Total Cost (Across Horizon): 1.96
# | Cost Theta (Across Horizon): 1.93
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 59
#
# | Total time: 39.0s
# | Step time: 370.7ms
# | Total Cost (Across Horizon): 2.04
# | Cost Theta (Across Horizon): 2.03
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 60
#
# | Total time: 39.3s
# | Step time: 355.9ms
# | Total Cost (Across Horizon): 2.67
# | Cost Theta (Across Horizon): 2.61
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 61
#
# | Total time: 39.7s
# | Step time: 342.7ms
# | Total Cost (Across Horizon): 1.45
# | Cost Theta (Across Horizon): 1.44
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 62
#
# | Total time: 40.0s
# | Step time: 357.2ms
# | Total Cost (Across Horizon): 5.68
# | Cost Theta (Across Horizon): 5.58
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 63
#
# | Total time: 40.4s
# | Step time: 340.2ms
# | Total Cost (Across Horizon): 1.40
# | Cost Theta (Across Horizon): 1.38
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 64
#
# | Total time: 40.7s
# | Step time: 339.0ms
# | Total Cost (Across Horizon): 0.97
# | Cost Theta (Across Horizon): 0.97
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 65
#
# | Total time: 41.1s
# | Step time: 363.3ms
# | Total Cost (Across Horizon): 1.64
# | Cost Theta (Across Horizon): 1.61
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 66
#
# | Total time: 41.4s
# | Step time: 336.1ms
# | Total Cost (Across Horizon): 0.72
# | Cost Theta (Across Horizon): 0.72
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 67
#
# | Total time: 41.9s
# | Step time: 467.2ms
# | Total Cost (Across Horizon): 1.60
# | Cost Theta (Across Horizon): 1.56
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 68
#
# | Total time: 42.5s
# | Step time: 576.5ms
# | Total Cost (Across Horizon): 1.41
# | Cost Theta (Across Horizon): 1.39
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 69
#
# | Total time: 43.0s
# | Step time: 537.5ms
# | Total Cost (Across Horizon): 1.07
# | Cost Theta (Across Horizon): 1.05
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 70
#
# | Total time: 43.6s
# | Step time: 546.3ms
# | Total Cost (Across Horizon): 0.64
# | Cost Theta (Across Horizon): 0.64
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 71
#
# | Total time: 44.1s
# | Step time: 520.2ms
# | Total Cost (Across Horizon): 1.17
# | Cost Theta (Across Horizon): 1.15
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 72
#
# | Total time: 44.6s
# | Step time: 509.4ms
# | Total Cost (Across Horizon): 3.54
# | Cost Theta (Across Horizon): 3.52
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.01
#
# | Step 73
#
# | Total time: 44.9s
# | Step time: 338.0ms
# | Total Cost (Across Horizon): 1.67
# | Cost Theta (Across Horizon): 1.67
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 74
#
# | Total time: 45.3s
# | Step time: 363.5ms
# | Total Cost (Across Horizon): 1.40
# | Cost Theta (Across Horizon): 1.37
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 75
#
# | Total time: 45.7s
# | Step time: 344.5ms
# | Total Cost (Across Horizon): 5.56
# | Cost Theta (Across Horizon): 5.49
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 76
#
# | Total time: 46.0s
# | Step time: 349.6ms
# | Total Cost (Across Horizon): 2.56
# | Cost Theta (Across Horizon): 2.53
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 77
#
# | Total time: 46.4s
# | Step time: 362.6ms
# | Total Cost (Across Horizon): 1.12
# | Cost Theta (Across Horizon): 1.10
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 78
#
# | Total time: 46.7s
# | Step time: 337.2ms
# | Total Cost (Across Horizon): 0.52
# | Cost Theta (Across Horizon): 0.51
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 79
#
# | Total time: 47.0s
# | Step time: 334.9ms
# | Total Cost (Across Horizon): 3.42
# | Cost Theta (Across Horizon): 3.30
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 80
#
# | Total time: 47.4s
# | Step time: 354.7ms
# | Total Cost (Across Horizon): 0.90
# | Cost Theta (Across Horizon): 0.89
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 81
#
# | Total time: 47.7s
# | Step time: 330.9ms
# | Total Cost (Across Horizon): 3.13
# | Cost Theta (Across Horizon): 3.03
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 82
#
# | Total time: 48.1s
# | Step time: 335.8ms
# | Total Cost (Across Horizon): 0.80
# | Cost Theta (Across Horizon): 0.79
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 83
#
# | Total time: 48.4s
# | Step time: 350.8ms
# | Total Cost (Across Horizon): 1.47
# | Cost Theta (Across Horizon): 1.46
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 84
#
# | Total time: 48.8s
# | Step time: 337.9ms
# | Total Cost (Across Horizon): 2.66
# | Cost Theta (Across Horizon): 2.61
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 85
#
# | Total time: 49.1s
# | Step time: 342.1ms
# | Total Cost (Across Horizon): 0.58
# | Cost Theta (Across Horizon): 0.57
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 86
#
# | Total time: 49.5s
# | Step time: 358.4ms
# | Total Cost (Across Horizon): 1.33
# | Cost Theta (Across Horizon): 1.32
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 87
#
# | Total time: 49.8s
# | Step time: 337.1ms
# | Total Cost (Across Horizon): 1.47
# | Cost Theta (Across Horizon): 1.46
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 88
#
# | Total time: 50.2s
# | Step time: 346.4ms
# | Total Cost (Across Horizon): 1.59
# | Cost Theta (Across Horizon): 1.57
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 89
#
# | Total time: 50.5s
# | Step time: 357.2ms
# | Total Cost (Across Horizon): 4.75
# | Cost Theta (Across Horizon): 4.68
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 90
#
# | Total time: 50.9s
# | Step time: 339.8ms
# | Total Cost (Across Horizon): 0.71
# | Cost Theta (Across Horizon): 0.67
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 91
#
# | Total time: 51.2s
# | Step time: 344.7ms
# | Total Cost (Across Horizon): 0.20
# | Cost Theta (Across Horizon): 0.20
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 92
#
# | Total time: 51.6s
# | Step time: 351.5ms
# | Total Cost (Across Horizon): 0.98
# | Cost Theta (Across Horizon): 0.96
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 93
#
# | Total time: 51.9s
# | Step time: 351.7ms
# | Total Cost (Across Horizon): 1.44
# | Cost Theta (Across Horizon): 1.41
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 94
#
# | Total time: 52.3s
# | Step time: 337.2ms
# | Total Cost (Across Horizon): 0.45
# | Cost Theta (Across Horizon): 0.44
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 95
#
# | Total time: 52.6s
# | Step time: 357.1ms
# | Total Cost (Across Horizon): 0.39
# | Cost Theta (Across Horizon): 0.38
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 96
#
# | Total time: 53.0s
# | Step time: 333.3ms
# | Total Cost (Across Horizon): 0.14
# | Cost Theta (Across Horizon): 0.13
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 97
#
# | Total time: 53.3s
# | Step time: 338.6ms
# | Total Cost (Across Horizon): 0.47
# | Cost Theta (Across Horizon): 0.47
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 98
#
# | Total time: 53.6s
# | Step time: 348.6ms
# | Total Cost (Across Horizon): 0.62
# | Cost Theta (Across Horizon): 0.62
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 99
#
# | Total time: 54.0s
# | Step time: 338.0ms
# | Total Cost (Across Horizon): 1.75
# | Cost Theta (Across Horizon): 1.73
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 100
#
# | Total time: 54.3s
# | Step time: 346.6ms
# | Total Cost (Across Horizon): 0.38
# | Cost Theta (Across Horizon): 0.38
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 101
#
# | Total time: 54.8s
# | Step time: 443.4ms
# | Total Cost (Across Horizon): 0.18
# | Cost Theta (Across Horizon): 0.18
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 102
#
# | Total time: 55.3s
# | Step time: 536.3ms
# | Total Cost (Across Horizon): 0.97
# | Cost Theta (Across Horizon): 0.97
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 103
#
# | Total time: 55.9s
# | Step time: 539.6ms
# | Total Cost (Across Horizon): 0.12
# | Cost Theta (Across Horizon): 0.11
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 104
#
# | Total time: 56.4s
# | Step time: 532.6ms
# | Total Cost (Across Horizon): 0.30
# | Cost Theta (Across Horizon): 0.29
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 105
#
# | Total time: 56.9s
# | Step time: 513.6ms
# | Total Cost (Across Horizon): 0.49
# | Cost Theta (Across Horizon): 0.47
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 106
#
# | Total time: 57.4s
# | Step time: 502.6ms
# | Total Cost (Across Horizon): 3.64
# | Cost Theta (Across Horizon): 3.57
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 107
#
# | Total time: 57.8s
# | Step time: 390.2ms
# | Total Cost (Across Horizon): 0.74
# | Cost Theta (Across Horizon): 0.71
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 108
#
# | Total time: 58.2s
# | Step time: 350.5ms
# | Total Cost (Across Horizon): 0.87
# | Cost Theta (Across Horizon): 0.85
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 109
#
# | Total time: 58.5s
# | Step time: 330.2ms
# | Total Cost (Across Horizon): 0.09
# | Cost Theta (Across Horizon): 0.09
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 110
#
# | Total time: 58.8s
# | Step time: 328.8ms
# | Total Cost (Across Horizon): 1.00
# | Cost Theta (Across Horizon): 0.97
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 111
#
# | Total time: 59.2s
# | Step time: 360.4ms
# | Total Cost (Across Horizon): 4.13
# | Cost Theta (Across Horizon): 4.05
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 112
#
# | Total time: 59.5s
# | Step time: 336.9ms
# | Total Cost (Across Horizon): 1.07
# | Cost Theta (Across Horizon): 1.06
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 113
#
# | Total time: 59.9s
# | Step time: 331.9ms
# | Total Cost (Across Horizon): 0.07
# | Cost Theta (Across Horizon): 0.06
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 114
#
# | Total time: 60.2s
# | Step time: 339.7ms
# | Total Cost (Across Horizon): 0.09
# | Cost Theta (Across Horizon): 0.09
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 115
#
# | Total time: 60.6s
# | Step time: 332.1ms
# | Total Cost (Across Horizon): 0.55
# | Cost Theta (Across Horizon): 0.55
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 116
#
# | Total time: 60.9s
# | Step time: 323.9ms
# | Total Cost (Across Horizon): 0.47
# | Cost Theta (Across Horizon): 0.46
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 117
#
# | Total time: 61.2s
# | Step time: 331.6ms
# | Total Cost (Across Horizon): 0.45
# | Cost Theta (Across Horizon): 0.43
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 118
#
# | Total time: 61.5s
# | Step time: 337.1ms
# | Total Cost (Across Horizon): 0.17
# | Cost Theta (Across Horizon): 0.17
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 119
#
# | Total time: 61.9s
# | Step time: 334.9ms
# | Total Cost (Across Horizon): 0.65
# | Cost Theta (Across Horizon): 0.64
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 120
#
# | Total time: 62.3s
# | Step time: 363.8ms
# | Total Cost (Across Horizon): 1.87
# | Cost Theta (Across Horizon): 1.85
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 121
#
# | Total time: 62.6s
# | Step time: 338.0ms
# | Total Cost (Across Horizon): 1.18
# | Cost Theta (Across Horizon): 1.16
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 122
#
# | Total time: 62.9s
# | Step time: 333.6ms
# | Total Cost (Across Horizon): 0.33
# | Cost Theta (Across Horizon): 0.33
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 123
#
# | Total time: 63.3s
# | Step time: 364.6ms
# | Total Cost (Across Horizon): 0.34
# | Cost Theta (Across Horizon): 0.33
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 124
#
# | Total time: 63.7s
# | Step time: 369.9ms
# | Total Cost (Across Horizon): 0.35
# | Cost Theta (Across Horizon): 0.35
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 125
#
# | Total time: 64.0s
# | Step time: 333.8ms
# | Total Cost (Across Horizon): 0.83
# | Cost Theta (Across Horizon): 0.82
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 126
#
# | Total time: 64.4s
# | Step time: 345.0ms
# | Total Cost (Across Horizon): 13.46
# | Cost Theta (Across Horizon): 13.18
# | Cost ThetaDot (Across Horizon): 0.03
# | Cost Control (Across Horizon): 0.00
#
# | Step 127
#
# | Total time: 64.7s
# | Step time: 345.8ms
# | Total Cost (Across Horizon): 0.67
# | Cost Theta (Across Horizon): 0.65
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 128
#
# | Total time: 65.0s
# | Step time: 338.9ms
# | Total Cost (Across Horizon): 6.47
# | Cost Theta (Across Horizon): 6.33
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 129
#
# | Total time: 65.4s
# | Step time: 337.8ms
# | Total Cost (Across Horizon): 0.43
# | Cost Theta (Across Horizon): 0.43
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 130
#
# | Total time: 65.7s
# | Step time: 337.7ms
# | Total Cost (Across Horizon): 0.24
# | Cost Theta (Across Horizon): 0.24
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 131
#
# | Total time: 66.1s
# | Step time: 342.4ms
# | Total Cost (Across Horizon): 3.46
# | Cost Theta (Across Horizon): 3.44
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 132
#
# | Total time: 66.4s
# | Step time: 351.4ms
# | Total Cost (Across Horizon): 2.77
# | Cost Theta (Across Horizon): 2.70
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 133
#
# | Total time: 66.8s
# | Step time: 332.9ms
# | Total Cost (Across Horizon): 0.73
# | Cost Theta (Across Horizon): 0.72
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 134
#
# | Total time: 67.1s
# | Step time: 340.4ms
# | Total Cost (Across Horizon): 0.13
# | Cost Theta (Across Horizon): 0.12
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 135
#
# | Total time: 67.4s
# | Step time: 332.6ms
# | Total Cost (Across Horizon): 0.59
# | Cost Theta (Across Horizon): 0.56
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 136
#
# | Total time: 67.8s
# | Step time: 407.3ms
# | Total Cost (Across Horizon): 0.87
# | Cost Theta (Across Horizon): 0.86
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 137
#
# | Total time: 68.4s
# | Step time: 557.1ms
# | Total Cost (Across Horizon): 1.59
# | Cost Theta (Across Horizon): 1.57
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 138
#
# | Total time: 68.9s
# | Step time: 534.6ms
# | Total Cost (Across Horizon): 0.09
# | Cost Theta (Across Horizon): 0.09
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 139
#
# | Total time: 69.5s
# | Step time: 545.9ms
# | Total Cost (Across Horizon): 2.27
# | Cost Theta (Across Horizon): 2.26
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 140
#
# | Total time: 70.0s
# | Step time: 493.9ms
# | Total Cost (Across Horizon): 0.75
# | Cost Theta (Across Horizon): 0.74
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 141
#
# | Total time: 70.5s
# | Step time: 497.5ms
# | Total Cost (Across Horizon): 1.34
# | Cost Theta (Across Horizon): 1.32
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 142
#
# | Total time: 70.9s
# | Step time: 399.0ms
# | Total Cost (Across Horizon): 0.97
# | Cost Theta (Across Horizon): 0.96
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 143
#
# | Total time: 71.2s
# | Step time: 341.2ms
# | Total Cost (Across Horizon): 0.76
# | Cost Theta (Across Horizon): 0.75
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 144
#
# | Total time: 71.6s
# | Step time: 353.6ms
# | Total Cost (Across Horizon): 0.52
# | Cost Theta (Across Horizon): 0.52
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 145
#
# | Total time: 71.9s
# | Step time: 336.5ms
# | Total Cost (Across Horizon): 0.26
# | Cost Theta (Across Horizon): 0.26
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 146
#
# | Total time: 72.3s
# | Step time: 351.0ms
# | Total Cost (Across Horizon): 1.51
# | Cost Theta (Across Horizon): 1.49
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 147
#
# | Total time: 72.7s
# | Step time: 366.5ms
# | Total Cost (Across Horizon): 0.26
# | Cost Theta (Across Horizon): 0.25
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 148
#
# | Total time: 73.0s
# | Step time: 336.4ms
# | Total Cost (Across Horizon): 6.36
# | Cost Theta (Across Horizon): 6.22
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 149
#
# | Total time: 73.3s
# | Step time: 332.5ms
# | Total Cost (Across Horizon): 2.08
# | Cost Theta (Across Horizon): 2.02
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 150
#
# | Total time: 73.7s
# | Step time: 363.3ms
# | Total Cost (Across Horizon): 1.47
# | Cost Theta (Across Horizon): 1.46
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 151
#
# | Total time: 74.0s
# | Step time: 339.0ms
# | Total Cost (Across Horizon): 2.58
# | Cost Theta (Across Horizon): 2.54
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 152
#
# | Total time: 74.4s
# | Step time: 345.2ms
# | Total Cost (Across Horizon): 0.71
# | Cost Theta (Across Horizon): 0.68
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 153
#
# | Total time: 74.7s
# | Step time: 349.1ms
# | Total Cost (Across Horizon): 13.79
# | Cost Theta (Across Horizon): 13.68
# | Cost ThetaDot (Across Horizon): 0.03
# | Cost Control (Across Horizon): 0.00
#
# | Step 154
#
# | Total time: 75.1s
# | Step time: 336.8ms
# | Total Cost (Across Horizon): 0.30
# | Cost Theta (Across Horizon): 0.29
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 155
#
# | Total time: 75.4s
# | Step time: 329.0ms
# | Total Cost (Across Horizon): 5.14
# | Cost Theta (Across Horizon): 5.06
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 156
#
# | Total time: 75.7s
# | Step time: 339.2ms
# | Total Cost (Across Horizon): 13.86
# | Cost Theta (Across Horizon): 13.60
# | Cost ThetaDot (Across Horizon): 0.03
# | Cost Control (Across Horizon): 0.00
#
# | Step 157
#
# | Total time: 76.1s
# | Step time: 337.2ms
# | Total Cost (Across Horizon): 0.70
# | Cost Theta (Across Horizon): 0.70
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 158
#
# | Total time: 76.4s
# | Step time: 333.5ms
# | Total Cost (Across Horizon): 0.66
# | Cost Theta (Across Horizon): 0.65
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 159
#
# | Total time: 76.8s
# | Step time: 341.7ms
# | Total Cost (Across Horizon): 5.63
# | Cost Theta (Across Horizon): 5.51
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 160
#
# | Total time: 77.1s
# | Step time: 343.1ms
# | Total Cost (Across Horizon): 1.50
# | Cost Theta (Across Horizon): 1.48
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 161
#
# | Total time: 77.4s
# | Step time: 327.0ms
# | Total Cost (Across Horizon): 1.97
# | Cost Theta (Across Horizon): 1.90
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 162
#
# | Total time: 77.8s
# | Step time: 327.2ms
# | Total Cost (Across Horizon): 0.40
# | Cost Theta (Across Horizon): 0.38
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 163
#
# | Total time: 78.1s
# | Step time: 352.8ms
# | Total Cost (Across Horizon): 0.31
# | Cost Theta (Across Horizon): 0.31
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 164
#
# | Total time: 78.5s
# | Step time: 332.7ms
# | Total Cost (Across Horizon): 1.21
# | Cost Theta (Across Horizon): 1.15
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 165
#
# | Total time: 78.8s
# | Step time: 328.0ms
# | Total Cost (Across Horizon): 3.38
# | Cost Theta (Across Horizon): 3.32
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 166
#
# | Total time: 79.1s
# | Step time: 351.1ms
# | Total Cost (Across Horizon): 0.80
# | Cost Theta (Across Horizon): 0.78
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 167
#
# | Total time: 79.5s
# | Step time: 331.5ms
# | Total Cost (Across Horizon): 0.26
# | Cost Theta (Across Horizon): 0.25
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 168
#
# | Total time: 79.8s
# | Step time: 335.5ms
# | Total Cost (Across Horizon): 0.86
# | Cost Theta (Across Horizon): 0.83
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 169
#
# | Total time: 80.2s
# | Step time: 343.5ms
# | Total Cost (Across Horizon): 2.03
# | Cost Theta (Across Horizon): 1.99
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 170
#
# | Total time: 80.5s
# | Step time: 335.4ms
# | Total Cost (Across Horizon): 2.06
# | Cost Theta (Across Horizon): 2.04
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 171
#
# | Total time: 80.9s
# | Step time: 406.7ms
# | Total Cost (Across Horizon): 0.18
# | Cost Theta (Across Horizon): 0.18
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 172
#
# | Total time: 81.4s
# | Step time: 522.8ms
# | Total Cost (Across Horizon): 0.64
# | Cost Theta (Across Horizon): 0.64
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 173
#
# | Total time: 82.0s
# | Step time: 527.7ms
# | Total Cost (Across Horizon): 0.34
# | Cost Theta (Across Horizon): 0.34
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 174
#
# | Total time: 82.5s
# | Step time: 560.5ms
# | Total Cost (Across Horizon): 1.28
# | Cost Theta (Across Horizon): 1.26
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 175
#
# | Total time: 83.1s
# | Step time: 528.8ms
# | Total Cost (Across Horizon): 1.01
# | Cost Theta (Across Horizon): 1.00
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 176
#
# | Total time: 83.6s
# | Step time: 533.5ms
# | Total Cost (Across Horizon): 0.41
# | Cost Theta (Across Horizon): 0.41
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 177
#
# | Total time: 84.0s
# | Step time: 418.6ms
# | Total Cost (Across Horizon): 2.34
# | Cost Theta (Across Horizon): 2.33
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 178
#
# | Total time: 84.4s
# | Step time: 353.1ms
# | Total Cost (Across Horizon): 1.84
# | Cost Theta (Across Horizon): 1.83
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 179
#
# | Total time: 84.7s
# | Step time: 340.5ms
# | Total Cost (Across Horizon): 5.33
# | Cost Theta (Across Horizon): 5.24
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 180
#
# | Total time: 85.1s
# | Step time: 338.1ms
# | Total Cost (Across Horizon): 1.14
# | Cost Theta (Across Horizon): 1.08
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 181
#
# | Total time: 85.4s
# | Step time: 355.9ms
# | Total Cost (Across Horizon): 1.64
# | Cost Theta (Across Horizon): 1.64
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 182
#
# | Total time: 85.8s
# | Step time: 337.1ms
# | Total Cost (Across Horizon): 1.14
# | Cost Theta (Across Horizon): 1.13
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 183
#
# | Total time: 86.1s
# | Step time: 334.5ms
# | Total Cost (Across Horizon): 1.15
# | Cost Theta (Across Horizon): 1.13
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 184
#
# | Total time: 86.5s
# | Step time: 350.6ms
# | Total Cost (Across Horizon): 0.54
# | Cost Theta (Across Horizon): 0.52
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 185
#
# | Total time: 86.8s
# | Step time: 331.7ms
# | Total Cost (Across Horizon): 1.36
# | Cost Theta (Across Horizon): 1.31
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 186
#
# | Total time: 87.1s
# | Step time: 340.5ms
# | Total Cost (Across Horizon): 3.35
# | Cost Theta (Across Horizon): 3.26
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 187
#
# | Total time: 87.5s
# | Step time: 350.6ms
# | Total Cost (Across Horizon): 0.91
# | Cost Theta (Across Horizon): 0.90
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 188
#
# | Total time: 87.8s
# | Step time: 331.9ms
# | Total Cost (Across Horizon): 1.13
# | Cost Theta (Across Horizon): 1.11
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 189
#
# | Total time: 88.2s
# | Step time: 342.2ms
# | Total Cost (Across Horizon): 0.51
# | Cost Theta (Across Horizon): 0.47
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 190
#
# | Total time: 88.5s
# | Step time: 357.1ms
# | Total Cost (Across Horizon): 0.78
# | Cost Theta (Across Horizon): 0.77
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 191
#
# | Total time: 88.9s
# | Step time: 344.0ms
# | Total Cost (Across Horizon): 0.89
# | Cost Theta (Across Horizon): 0.86
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 192
#
# | Total time: 89.2s
# | Step time: 339.5ms
# | Total Cost (Across Horizon): 2.08
# | Cost Theta (Across Horizon): 2.06
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 193
#
# | Total time: 89.6s
# | Step time: 347.8ms
# | Total Cost (Across Horizon): 2.04
# | Cost Theta (Across Horizon): 2.00
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 194
#
# | Total time: 89.9s
# | Step time: 338.1ms
# | Total Cost (Across Horizon): 2.18
# | Cost Theta (Across Horizon): 2.12
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 195
#
# | Total time: 90.2s
# | Step time: 343.2ms
# | Total Cost (Across Horizon): 1.12
# | Cost Theta (Across Horizon): 1.12
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 196
#
# | Total time: 90.6s
# | Step time: 348.6ms
# | Total Cost (Across Horizon): 0.55
# | Cost Theta (Across Horizon): 0.54
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 197
#
# | Total time: 90.9s
# | Step time: 335.1ms
# | Total Cost (Across Horizon): 3.43
# | Cost Theta (Across Horizon): 3.34
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 198
#
# | Total time: 91.3s
# | Step time: 338.2ms
# | Total Cost (Across Horizon): 1.48
# | Cost Theta (Across Horizon): 1.44
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 199
#
# | Total time: 91.6s
# | Step time: 353.7ms
# | Total Cost (Across Horizon): 8.49
# | Cost Theta (Across Horizon): 8.36
# | Cost ThetaDot (Across Horizon): 0.02
# | Cost Control (Across Horizon): 0.00
#
# | Step 200
#
# | Total time: 92.0s
# | Step time: 338.9ms
# | Total Cost (Across Horizon): 0.12
# | Cost Theta (Across Horizon): 0.12
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 201
#
# | Total time: 92.3s
# | Step time: 341.8ms
# | Total Cost (Across Horizon): 3.46
# | Cost Theta (Across Horizon): 3.36
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 202
#
# | Total time: 92.7s
# | Step time: 348.6ms
# | Total Cost (Across Horizon): 0.69
# | Cost Theta (Across Horizon): 0.66
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 203
#
# | Total time: 93.0s
# | Step time: 346.7ms
# | Total Cost (Across Horizon): 0.30
# | Cost Theta (Across Horizon): 0.30
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 204
#
# | Total time: 93.4s
# | Step time: 345.8ms
# | Total Cost (Across Horizon): 0.39
# | Cost Theta (Across Horizon): 0.39
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 205
#
# | Total time: 93.7s
# | Step time: 386.4ms
# | Total Cost (Across Horizon): 4.64
# | Cost Theta (Across Horizon): 4.57
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.01
#
# | Step 206
#
# | Total time: 94.2s
# | Step time: 493.5ms
# | Total Cost (Across Horizon): 2.65
# | Cost Theta (Across Horizon): 2.61
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 207
#
# | Total time: 94.8s
# | Step time: 552.2ms
# | Total Cost (Across Horizon): 0.86
# | Cost Theta (Across Horizon): 0.85
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 208
#
# | Total time: 95.3s
# | Step time: 534.4ms
# | Total Cost (Across Horizon): 1.20
# | Cost Theta (Across Horizon): 1.19
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 209
#
# | Total time: 95.9s
# | Step time: 550.7ms
# | Total Cost (Across Horizon): 0.65
# | Cost Theta (Across Horizon): 0.64
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 210
#
# | Total time: 96.4s
# | Step time: 521.0ms
# | Total Cost (Across Horizon): 3.68
# | Cost Theta (Across Horizon): 3.62
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 211
#
# | Total time: 97.0s
# | Step time: 560.0ms
# | Total Cost (Across Horizon): 3.49
# | Cost Theta (Across Horizon): 3.42
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 212
#
# | Total time: 97.4s
# | Step time: 367.0ms
# | Total Cost (Across Horizon): 0.29
# | Cost Theta (Across Horizon): 0.29
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 213
#
# | Total time: 97.7s
# | Step time: 339.4ms
# | Total Cost (Across Horizon): 2.43
# | Cost Theta (Across Horizon): 2.42
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 214
#
# | Total time: 98.0s
# | Step time: 349.2ms
# | Total Cost (Across Horizon): 0.74
# | Cost Theta (Across Horizon): 0.72
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 215
#
# | Total time: 98.4s
# | Step time: 336.7ms
# | Total Cost (Across Horizon): 3.08
# | Cost Theta (Across Horizon): 3.02
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 216
#
# | Total time: 98.7s
# | Step time: 335.1ms
# | Total Cost (Across Horizon): 1.54
# | Cost Theta (Across Horizon): 1.53
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 217
#
# | Total time: 99.1s
# | Step time: 348.0ms
# | Total Cost (Across Horizon): 0.26
# | Cost Theta (Across Horizon): 0.26
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 218
#
# | Total time: 99.4s
# | Step time: 334.3ms
# | Total Cost (Across Horizon): 0.71
# | Cost Theta (Across Horizon): 0.69
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 219
#
# | Total time: 99.7s
# | Step time: 326.7ms
# | Total Cost (Across Horizon): 3.03
# | Cost Theta (Across Horizon): 3.01
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 220
#
# | Total time: 100.1s
# | Step time: 345.8ms
# | Total Cost (Across Horizon): 2.24
# | Cost Theta (Across Horizon): 2.20
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 221
#
# | Total time: 100.4s
# | Step time: 333.9ms
# | Total Cost (Across Horizon): 0.94
# | Cost Theta (Across Horizon): 0.93
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 222
#
# | Total time: 100.8s
# | Step time: 329.8ms
# | Total Cost (Across Horizon): 0.31
# | Cost Theta (Across Horizon): 0.30
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 223
#
# | Total time: 101.1s
# | Step time: 343.9ms
# | Total Cost (Across Horizon): 0.26
# | Cost Theta (Across Horizon): 0.25
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 224
#
# | Total time: 101.4s
# | Step time: 334.4ms
# | Total Cost (Across Horizon): 1.78
# | Cost Theta (Across Horizon): 1.77
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 225
#
# | Total time: 101.8s
# | Step time: 330.0ms
# | Total Cost (Across Horizon): 1.64
# | Cost Theta (Across Horizon): 1.61
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 226
#
# | Total time: 102.1s
# | Step time: 343.9ms
# | Total Cost (Across Horizon): 4.70
# | Cost Theta (Across Horizon): 4.59
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 227
#
# | Total time: 102.5s
# | Step time: 343.3ms
# | Total Cost (Across Horizon): 1.25
# | Cost Theta (Across Horizon): 1.23
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 228
#
# | Total time: 102.8s
# | Step time: 334.3ms
# | Total Cost (Across Horizon): 2.14
# | Cost Theta (Across Horizon): 2.12
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 229
#
# | Total time: 103.1s
# | Step time: 335.4ms
# | Total Cost (Across Horizon): 0.35
# | Cost Theta (Across Horizon): 0.35
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 230
#
# | Total time: 103.5s
# | Step time: 359.4ms
# | Total Cost (Across Horizon): 0.93
# | Cost Theta (Across Horizon): 0.90
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 231
#
# | Total time: 103.8s
# | Step time: 322.9ms
# | Total Cost (Across Horizon): 0.58
# | Cost Theta (Across Horizon): 0.56
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 232
#
# | Total time: 104.2s
# | Step time: 333.7ms
# | Total Cost (Across Horizon): 0.63
# | Cost Theta (Across Horizon): 0.61
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 233
#
# | Total time: 104.5s
# | Step time: 354.3ms
# | Total Cost (Across Horizon): 0.14
# | Cost Theta (Across Horizon): 0.13
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 234
#
# | Total time: 104.9s
# | Step time: 332.1ms
# | Total Cost (Across Horizon): 0.42
# | Cost Theta (Across Horizon): 0.41
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 235
#
# | Total time: 105.2s
# | Step time: 340.5ms
# | Total Cost (Across Horizon): 0.31
# | Cost Theta (Across Horizon): 0.30
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 236
#
# | Total time: 105.6s
# | Step time: 355.6ms
# | Total Cost (Across Horizon): 0.63
# | Cost Theta (Across Horizon): 0.63
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 237
#
# | Total time: 105.9s
# | Step time: 337.5ms
# | Total Cost (Across Horizon): 2.20
# | Cost Theta (Across Horizon): 2.17
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 238
#
# | Total time: 106.2s
# | Step time: 337.8ms
# | Total Cost (Across Horizon): 0.26
# | Cost Theta (Across Horizon): 0.26
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 239
#
# | Total time: 106.6s
# | Step time: 350.2ms
# | Total Cost (Across Horizon): 0.32
# | Cost Theta (Across Horizon): 0.32
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 240
#
# | Total time: 106.9s
# | Step time: 327.1ms
# | Total Cost (Across Horizon): 4.43
# | Cost Theta (Across Horizon): 4.35
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 241
#
# | Total time: 107.4s
# | Step time: 464.0ms
# | Total Cost (Across Horizon): 1.34
# | Cost Theta (Across Horizon): 1.32
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 242
#
# | Total time: 107.9s
# | Step time: 519.4ms
# | Total Cost (Across Horizon): 1.24
# | Cost Theta (Across Horizon): 1.22
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 243
#
# | Total time: 108.6s
# | Step time: 710.4ms
# | Total Cost (Across Horizon): 2.14
# | Cost Theta (Across Horizon): 2.09
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 244
#
# | Total time: 109.2s
# | Step time: 550.0ms
# | Total Cost (Across Horizon): 0.17
# | Cost Theta (Across Horizon): 0.16
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 245
#
# | Total time: 109.7s
# | Step time: 542.9ms
# | Total Cost (Across Horizon): 0.31
# | Cost Theta (Across Horizon): 0.31
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 246
#
# | Total time: 110.3s
# | Step time: 546.5ms
# | Total Cost (Across Horizon): 5.09
# | Cost Theta (Across Horizon): 4.98
# | Cost ThetaDot (Across Horizon): 0.01
# | Cost Control (Across Horizon): 0.00
#
# | Step 247
#
# | Total time: 110.7s
# | Step time: 395.5ms
# | Total Cost (Across Horizon): 0.21
# | Cost Theta (Across Horizon): 0.21
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 248
#
# | Total time: 111.0s
# | Step time: 340.9ms
# | Total Cost (Across Horizon): 0.22
# | Cost Theta (Across Horizon): 0.22
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
#
# | Step 249
#
# | Total time: 111.4s
# | Step time: 339.6ms
# | Total Cost (Across Horizon): 1.57
# | Cost Theta (Across Horizon): 1.52
# | Cost ThetaDot (Across Horizon): 0.00
# | Cost Control (Across Horizon): 0.00
# /usr/lib/python3.10/subprocess.py:1796: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _posixsubprocess.fork_exec(
#
# Video saved: pendulum_video.mp4

# %%
from IPython.display import Video
Video("pendulum_video.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
