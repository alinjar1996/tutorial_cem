# %% [markdown]
# <a href="https://colab.research.google.com/github/alinjar1996/tutorial_cem/blob/main/tutorial_biped.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update
# !sudo apt-get install python3.10 python3.10-venv python3.10-distutils
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,388 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.2 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,922 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:16 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [39.2 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,780 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,813 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,877 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,301 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,652 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,120 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,613 kB]
# Fetched 40.0 MB in 3s (12.7 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.10-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# python3-distutils set to manually installed.
# python3.10 is already the newest version (3.10.12-1~22.04.14).
# python3.10 set to manually installed.
# The following NEW packages will be installed:
#   python3-pip-whl python3-setuptools-whl python3.10-venv
# 0 upgraded, 3 newly installed, 0 to remove and 98 not upgraded.
# Need to get 2,481 kB of archives.
# After this operation, 2,754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.7 [1,683 kB]
# Get:2 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 python3-setuptools-whl all 68.1.2-2~jammy3 [792 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3.10-venv amd64 3.10.12-1~22.04.14 [5,724 B]
# Fetched 2,481 kB in 2s (997 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python3-pip-whl.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../python3-pip-whl_22.0.2+dfsg-1ubuntu0.7_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.7) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../python3-setuptools-whl_68.1.2-2~jammy3_all.deb ...
# Unpacking python3-setuptools-whl (68.1.2-2~jammy3) ...
# Selecting previously unselected package python3.10-venv.
# Preparing to unpack .../python3.10-venv_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking python3.10-venv (3.10.12-1~22.04.14) ...
# Setting up python3-setuptools-whl (68.1.2-2~jammy3) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.7) ...
# Setting up python3.10-venv (3.10.12-1~22.04.14) ...

# %%
# !python3.10 -m venv py310_env

# %%
# !py310_env/bin/python -m ensurepip
# !py310_env/bin/pip install pip==22.0.2
# Out:
# Looking in links: /tmp/tmp3a06fmrm
# Requirement already satisfied: setuptools in ./py310_env/lib/python3.10/site-packages (68.1.2)
# Requirement already satisfied: pip in ./py310_env/lib/python3.10/site-packages (22.0.2)
# Requirement already satisfied: pip==22.0.2 in ./py310_env/lib/python3.10/site-packages (22.0.2)

# %%
# !py310_env/bin/python --version
# !py310_env/bin/pip --version
# Out:
# Python 3.10.12
# pip 22.0.2 from /content/py310_env/lib/python3.10/site-packages/pip (python 3.10)

# %%
# !git clone https://github.com/alinjar1996/sampling_based_general.git -b issue_1_biped_torque
# Out:
# Cloning into 'sampling_based_general'...
# remote: Enumerating objects: 3914, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 3914 (delta 95), reused 100 (delta 50), pack-reused 3759 (from 2)
# Receiving objects: 100% (3914/3914), 573.78 MiB | 31.30 MiB/s, done.
# Resolving deltas: 100% (1945/1945), done.
# Updating files: 100% (830/830), done.

# %%
# %cd /content/sampling_based_general
# !git pull
# Out:
# /content/sampling_based_general
# Already up to date.

# %%
# !ls /content
# !/content/py310_env/bin/pip install -r requirements.txt
# Out:
# py310_env  sample_data	sampling_based_general
# Collecting absl-py==2.2.2
#   Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 KB 2.6 MB/s eta 0:00:00
# Collecting asttokens==3.0.0
#   Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Collecting cffi==1.17.1
#   Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 KB 7.6 MB/s eta 0:00:00
# Collecting clarabel==0.11.0
#   Downloading clarabel-0.11.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.3 MB/s eta 0:00:00
# Collecting comm==0.2.2
#   Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Collecting contourpy==1.3.1
#   Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 KB 14.4 MB/s eta 0:00:00
# Collecting cycler==0.12.1
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting debugpy==1.8.14
#   Downloading debugpy-1.8.14-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 19.6 MB/s eta 0:00:00
# Collecting decorator==5.2.1
#   Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Collecting etils==1.12.2
#   Downloading etils-1.12.2-py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 KB 27.4 MB/s eta 0:00:00
# Collecting executing==2.2.0
#   Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Collecting filelock==3.18.0
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting fonttools==4.57.0
#   Downloading fonttools-4.57.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 31.5 MB/s eta 0:00:00
# Collecting fsspec==2025.3.2
#   Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 KB 23.4 MB/s eta 0:00:00
# Collecting glfw==2.8.0
#   Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 KB 37.6 MB/s eta 0:00:00
# Collecting importlib_resources==6.5.2
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting ipykernel==6.29.5
#   Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 KB 15.0 MB/s eta 0:00:00
# Collecting ipython==8.38.0
#   Downloading ipython-8.38.0-py3-none-any.whl (831 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.8/831.8 KB 36.8 MB/s eta 0:00:00
# Collecting ipython_pygments_lexers==1.1.1
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Collecting jax==0.5.3
#   Downloading jax-0.5.3-py3-none-any.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 41.2 MB/s eta 0:00:00
# Collecting jax-cuda12-pjrt==0.5.3
#   Downloading jax_cuda12_pjrt-0.5.3-py3-none-manylinux2014_x86_64.whl (104.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.7/104.7 MB 8.8 MB/s eta 0:00:00
# Collecting jax-cuda12-plugin==0.5.3
#   Downloading jax_cuda12_plugin-0.5.3-cp310-cp310-manylinux2014_x86_64.whl (16.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 76.5 MB/s eta 0:00:00
# Collecting jaxlib==0.5.3
#   Downloading jaxlib-0.5.3-cp310-cp310-manylinux2014_x86_64.whl (105.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 MB 8.8 MB/s eta 0:00:00
# Collecting jedi==0.19.2
#   Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 102.4 MB/s eta 0:00:00
# Collecting Jinja2==3.1.6
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 KB 26.8 MB/s eta 0:00:00
# Collecting joblib==1.5.1
#   Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 KB 48.7 MB/s eta 0:00:00
# Collecting jupyter_client==8.6.3
#   Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 KB 21.3 MB/s eta 0:00:00
# Collecting jupyter_core==5.7.2
#   Downloading jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Collecting kiwisolver==1.4.8
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 108.3 MB/s eta 0:00:00
# Collecting MarkupSafe==3.0.2
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Collecting matplotlib==3.10.1
#   Downloading matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 104.4 MB/s eta 0:00:00
# Collecting matplotlib-inline==0.1.7
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Collecting ml_dtypes==0.5.1
#   Downloading ml_dtypes-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 143.1 MB/s eta 0:00:00
# Collecting mpmath==1.3.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 71.3 MB/s eta 0:00:00
# Collecting mujoco==3.3.1
#   Downloading mujoco-3.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 109.8 MB/s eta 0:00:00
# Collecting mujoco-mjx==3.3.1
#   Downloading mujoco_mjx-3.3.1-py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 37.4 MB/s eta 0:00:00
# Collecting nest-asyncio==1.6.0
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Collecting networkx==3.4.2
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 110.3 MB/s eta 0:00:00
# Collecting numpy==2.2.4
#   Downloading numpy-2.2.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 69.4 MB/s eta 0:00:00
# Collecting opt_einsum==3.4.0
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 KB 9.0 MB/s eta 0:00:00
# Collecting osqp==1.0.4
#   Downloading osqp-1.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (344 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.6/344.6 KB 47.0 MB/s eta 0:00:00
# Collecting packaging==24.2
#   Downloading packaging-24.2-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 KB 10.4 MB/s eta 0:00:00
# Collecting parso==0.8.4
#   Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.7/103.7 KB 20.2 MB/s eta 0:00:00
# Collecting pexpect==4.9.0
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 KB 11.7 MB/s eta 0:00:00
# Collecting pillow==11.2.1
#   Downloading pillow-11.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 130.9 MB/s eta 0:00:00
# Collecting platformdirs==4.3.8
#   Downloading platformdirs-4.3.8-py3-none-any.whl (18 kB)
# Collecting prompt_toolkit==3.0.51
#   Downloading prompt_toolkit-3.0.51-py3-none-any.whl (387 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.8/387.8 KB 53.1 MB/s eta 0:00:00
# Collecting psutil==7.0.0
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 KB 40.3 MB/s eta 0:00:00
# Collecting ptyprocess==0.7.0
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting pure_eval==0.2.3
#   Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Collecting pycparser==2.22
#   Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 KB 25.1 MB/s eta 0:00:00
# Collecting Pygments==2.19.1
#   Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 86.4 MB/s eta 0:00:00
# Collecting PyOpenGL==3.1.9
#   Downloading PyOpenGL-3.1.9-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 138.7 MB/s eta 0:00:00
# Collecting pyparsing==3.2.3
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 KB 23.2 MB/s eta 0:00:00
# Collecting python-dateutil==2.9.0.post0
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 KB 44.3 MB/s eta 0:00:00
# Collecting pyzmq==26.4.0
#   Downloading pyzmq-26.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (862 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.5/862.5 KB 59.0 MB/s eta 0:00:00
# Collecting qpsolvers==4.7.0
#   Downloading qpsolvers-4.7.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 KB 20.4 MB/s eta 0:00:00
# Collecting scipy==1.15.2
#   Downloading scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 21.7 MB/s eta 0:00:00
# Collecting setuptools==80.8.0
#   Downloading setuptools-80.8.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 93.8 MB/s eta 0:00:00
# Collecting six==1.17.0
#   Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Collecting stack-data==0.6.3
#   Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Collecting sympy==1.13.1
#   Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 133.9 MB/s eta 0:00:00
# Collecting traitlets==5.14.3
#   Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 KB 16.5 MB/s eta 0:00:00
# Collecting trimesh==4.6.6
#   Downloading trimesh-4.6.6-py3-none-any.whl (709 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 KB 77.0 MB/s eta 0:00:00
# Collecting triton==3.1.0
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 5.5 MB/s eta 0:00:00
# Collecting typing_extensions==4.13.2
#   Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 KB 4.3 MB/s eta 0:00:00
# Collecting wcwidth==0.2.13
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Collecting zipp==3.21.0
#   Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Collecting qpsolvers[daqp]
#   Downloading qpsolvers-4.9.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 KB 15.4 MB/s eta 0:00:00
# Collecting tornado>=6.1
#   Downloading tornado-6.5.4-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (445 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.3/445.3 KB 54.4 MB/s eta 0:00:00
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Collecting etils[epath]
#   Downloading etils-1.13.0-py3-none-any.whl (170 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.6/170.6 KB 31.0 MB/s eta 0:00:00
# Collecting qpsolvers[daqp]
#   Downloading qpsolvers-4.8.2-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 KB 17.7 MB/s eta 0:00:00
#   Downloading qpsolvers-4.8.1-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 KB 18.7 MB/s eta 0:00:00
#   Downloading qpsolvers-4.8.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 KB 19.8 MB/s eta 0:00:00
#   Downloading qpsolvers-4.7.1-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 KB 19.4 MB/s eta 0:00:00
# Collecting daqp>=0.5.1
#   Downloading daqp-0.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (595 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 595.9/595.9 KB 63.5 MB/s eta 0:00:00
# Installing collected packages: wcwidth, PyOpenGL, pure_eval, ptyprocess, mpmath, jax-cuda12-pjrt, glfw, daqp, zipp, typing_extensions, traitlets, tornado, sympy, six, setuptools, pyzmq, pyparsing, Pygments, pycparser, psutil, prompt_toolkit, platformdirs, pillow, pexpect, parso, packaging, opt_einsum, numpy, networkx, nest-asyncio, MarkupSafe, kiwisolver, joblib, jax-cuda12-plugin, importlib_resources, fsspec, fonttools, filelock, executing, etils, decorator, debugpy, cycler, asttokens, absl-py, triton, trimesh, stack-data, scipy, python-dateutil, ml_dtypes, matplotlib-inline, jupyter_core, Jinja2, jedi, ipython_pygments_lexers, exceptiongroup, contourpy, comm, cffi, qpsolvers, osqp, matplotlib, jupyter_client, jaxlib, ipython, clarabel, mujoco, jax, ipykernel, mujoco-mjx
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.1.2
#     Uninstalling setuptools-68.1.2:
#       Successfully uninstalled setuptools-68.1.2
# Successfully installed Jinja2-3.1.6 MarkupSafe-3.0.2 PyOpenGL-3.1.9 Pygments-2.19.1 absl-py-2.2.2 asttokens-3.0.0 cffi-1.17.1 clarabel-0.11.0 comm-0.2.2 contourpy-1.3.1 cycler-0.12.1 daqp-0.7.2 debugpy-1.8.14 decorator-5.2.1 etils-1.12.2 exceptiongroup-1.3.1 executing-2.2.0 filelock-3.18.0 fonttools-4.57.0 fsspec-2025.3.2 glfw-2.8.0 importlib_resources-6.5.2 ipykernel-6.29.5 ipython-8.38.0 ipython_pygments_lexers-1.1.1 jax-0.5.3 jax-cuda12-pjrt-0.5.3 jax-cuda12-plugin-0.5.3 jaxlib-0.5.3 jedi-0.19.2 joblib-1.5.1 jupyter_client-8.6.3 jupyter_core-5.7.2 kiwisolver-1.4.8 matplotlib-3.10.1 matplotlib-inline-0.1.7 ml_dtypes-0.5.1 mpmath-1.3.0 mujoco-3.3.1 mujoco-mjx-3.3.1 nest-asyncio-1.6.0 networkx-3.4.2 numpy-2.2.4 opt_einsum-3.4.0 osqp-1.0.4 packaging-24.2 parso-0.8.4 pexpect-4.9.0 pillow-11.2.1 platformdirs-4.3.8 prompt_toolkit-3.0.51 psutil-7.0.0 ptyprocess-0.7.0 pure_eval-0.2.3 pycparser-2.22 pyparsing-3.2.3 python-dateutil-2.9.0.post0 pyzmq-26.4.0 qpsolvers-4.7.0 scipy-1.15.2 setuptools-80.8.0 six-1.17.0 stack-data-0.6.3 sympy-1.13.1 tornado-6.5.4 traitlets-5.14.3 trimesh-4.6.6 triton-3.1.0 typing_extensions-4.13.2 wcwidth-0.2.13 zipp-3.21.0

# %%
# %cd /content/sampling_based_general/real_demo

# !git clone https://github.com/AKS-Lab-Univertsity-of-Tartu/math_utils_aks_lab.git math_utils
# Out:
# /content/sampling_based_general/real_demo
# Cloning into 'math_utils'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 123 (delta 62), reused 106 (delta 47), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 12.73 MiB | 29.97 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
# %cd /content/sampling_based_general
# Out:
# /content/sampling_based_general

# %%
# !apt-get update
# !apt-get install -y libgl1-mesa-dev libegl1-mesa-dev
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libegl-dev libgl-dev libgles-dev libgles1 libglvnd-core-dev libglvnd-dev
#   libglx-dev libopengl-dev
# The following NEW packages will be installed:
#   libegl-dev libegl1-mesa-dev libgl-dev libgl1-mesa-dev libgles-dev libgles1
#   libglvnd-core-dev libglvnd-dev libglx-dev libopengl-dev
# 0 upgraded, 10 newly installed, 0 to remove and 98 not upgraded.
# Need to get 232 kB of archives.
# After this operation, 2,678 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libegl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [11.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [6,848 B]
# Fetched 232 kB in 1s (381 kB/s)
# Selecting previously unselected package libglx-dev:amd64.
# (Reading database ... 121867 files and directories currently installed.)
# Preparing to unpack .../0-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../1-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../2-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../3-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../4-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../5-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../6-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../7-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl1-mesa-dev:amd64.
# Preparing to unpack .../8-libegl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../9-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link

# %%
# !/content/py310_env/bin/pip install imageio[ffmpeg]
# Out:
# Collecting imageio[ffmpeg]
#   Downloading imageio-2.37.2-py3-none-any.whl (317 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.6/317.6 KB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /content/py310_env/lib/python3.10/site-packages (from imageio[ffmpeg]) (2.2.4)
# Requirement already satisfied: pillow>=8.3.2 in /content/py310_env/lib/python3.10/site-packages (from imageio[ffmpeg]) (11.2.1)
# Collecting imageio-ffmpeg
#   Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl (29.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /content/py310_env/lib/python3.10/site-packages (from imageio[ffmpeg]) (7.0.0)
# Installing collected packages: imageio-ffmpeg, imageio
# Successfully installed imageio-2.37.2 imageio-ffmpeg-0.6.0

# %%
# !python3 -u real_demo/pendulum_demo_pyt_colab.py
# !/content/py310_env/bin/python3.10 real_demo/pendulum_demo_pyt_colab.py --num_batch 500 --maxiter_cem 1 --steps 100
# !/content/py310_env/bin/python3.10 \
    real_demo/walker_demo_pyt_colab.py \
    --num_batch 50 \
    --maxiter_cem 30 \
    --steps 100 \
    --timestep 0.02 \
    --maxiter_projection 1 \
    --num_steps 50
# Out:
# Sensors: 0 1 2
#
# Torque-controlled joints:
#   0: 'rootz' -> controlled: False
#   1: 'rootx' -> controlled: False
#   2: 'rooty' -> controlled: False
#   3: 'right_hip' -> controlled: True
#   4: 'right_knee' -> controlled: True
#   5: 'right_ankle' -> controlled: True
#   6: 'left_hip' -> controlled: True
#   7: 'left_knee' -> controlled: True
#   8: 'left_ankle' -> controlled: True
#
#  Default backend: gpu
#  Timestep: 0.02
#  CEM Iter: 30
#  Projection Iter: 1
#  Number of batches: 50
#  Number of steps per trajectory: 50
#  Time per trajectory: 1.0
#  Number of variables: 66
#  Number of Total constraints: 1800
#
# Step 0
#
# Torso Position: [0.  0.  1.3]
#
# | Total time: 24.5s
# | Step time: 24536.0ms
# | Total Cost (Across Horizon): 725.69
# | Cost Height (Across Horizon): 4.62
# | Cost Orientation (Across Horizon): 1.22
# | Velocity (Across Horizon): 716.60
# | Control (Across Horizon): 3.25
#
# Step 1
#
# Torso Position: [-0.      0.      1.2961]
#
# | Total time: 25.9s
# | Step time: 1307.0ms
# | Total Cost (Across Horizon): 461.95
# | Cost Height (Across Horizon): 14.29
# | Cost Orientation (Across Horizon): 1.44
# | Velocity (Across Horizon): 442.64
# | Control (Across Horizon): 3.59
#
# Step 2
#
# Torso Position: [-0.0006  0.      1.2939]
#
# | Total time: 26.9s
# | Step time: 1003.0ms
# | Total Cost (Across Horizon): 448.21
# | Cost Height (Across Horizon): 15.50
# | Cost Orientation (Across Horizon): 1.40
# | Velocity (Across Horizon): 427.71
# | Control (Across Horizon): 3.61
#
# Step 3
#
# Torso Position: [-0.0043  0.      1.2947]
#
# | Total time: 27.9s
# | Step time: 1006.8ms
# | Total Cost (Across Horizon): 556.99
# | Cost Height (Across Horizon): 7.63
# | Cost Orientation (Across Horizon): 1.19
# | Velocity (Across Horizon): 544.59
# | Control (Across Horizon): 3.59
#
# Step 4
#
# Torso Position: [-0.0108  0.      1.2973]
#
# | Total time: 29.2s
# | Step time: 1246.3ms
# | Total Cost (Across Horizon): 509.71
# | Cost Height (Across Horizon): 18.60
# | Cost Orientation (Across Horizon): 4.16
# | Velocity (Across Horizon): 483.32
# | Control (Across Horizon): 3.64
#
# Step 5
#
# Torso Position: [-0.0194  0.      1.2952]
#
# | Total time: 30.4s
# | Step time: 1206.7ms
# | Total Cost (Across Horizon): 431.49
# | Cost Height (Across Horizon): 11.57
# | Cost Orientation (Across Horizon): 2.18
# | Velocity (Across Horizon): 414.27
# | Control (Across Horizon): 3.47
#
# Step 6
#
# Torso Position: [-0.0279  0.      1.2963]
#
# | Total time: 31.5s
# | Step time: 1072.1ms
# | Total Cost (Across Horizon): 377.09
# | Cost Height (Across Horizon): 14.28
# | Cost Orientation (Across Horizon): 2.25
# | Velocity (Across Horizon): 357.13
# | Control (Across Horizon): 3.43
#
# Step 7
#
# Torso Position: [-0.0363  0.      1.2928]
#
# | Total time: 32.5s
# | Step time: 1000.5ms
# | Total Cost (Across Horizon): 660.14
# | Cost Height (Across Horizon): 6.18
# | Cost Orientation (Across Horizon): 1.16
# | Velocity (Across Horizon): 649.26
# | Control (Across Horizon): 3.54
#
# Step 8
#
# Torso Position: [-0.0407  0.      1.2835]
#
# | Total time: 33.5s
# | Step time: 1012.0ms
# | Total Cost (Across Horizon): 320.71
# | Cost Height (Across Horizon): 15.31
# | Cost Orientation (Across Horizon): 1.62
# | Velocity (Across Horizon): 300.49
# | Control (Across Horizon): 3.28
#
# Step 9
#
# Torso Position: [-0.0393  0.      1.289 ]
#
# | Total time: 34.5s
# | Step time: 1006.0ms
# | Total Cost (Across Horizon): 358.33
# | Cost Height (Across Horizon): 14.66
# | Cost Orientation (Across Horizon): 2.08
# | Velocity (Across Horizon): 338.51
# | Control (Across Horizon): 3.09
#
# Step 10
#
# Torso Position: [-0.0322  0.      1.3095]
#
# | Total time: 35.5s
# | Step time: 1016.2ms
# | Total Cost (Across Horizon): 609.24
# | Cost Height (Across Horizon): 15.91
# | Cost Orientation (Across Horizon): 4.46
# | Velocity (Across Horizon): 585.63
# | Control (Across Horizon): 3.24
#
# Step 11
#
# Torso Position: [-0.0203  0.      1.3386]
#
# | Total time: 36.5s
# | Step time: 1007.4ms
# | Total Cost (Across Horizon): 618.99
# | Cost Height (Across Horizon): 16.52
# | Cost Orientation (Across Horizon): 3.94
# | Velocity (Across Horizon): 595.37
# | Control (Across Horizon): 3.16
#
# Step 12
#
# Torso Position: [-0.0102  0.      1.3576]
#
# | Total time: 37.5s
# | Step time: 998.1ms
# | Total Cost (Across Horizon): 609.63
# | Cost Height (Across Horizon): 15.85
# | Cost Orientation (Across Horizon): 3.96
# | Velocity (Across Horizon): 586.68
# | Control (Across Horizon): 3.14
#
# Step 13
#
# Torso Position: [-0.0014  0.      1.3663]
#
# | Total time: 38.5s
# | Step time: 1007.3ms
# | Total Cost (Across Horizon): 544.19
# | Cost Height (Across Horizon): 12.83
# | Cost Orientation (Across Horizon): 4.04
# | Velocity (Across Horizon): 524.19
# | Control (Across Horizon): 3.13
#
# Step 14
#
# Torso Position: [0.0096 0.     1.3684]
#
# | Total time: 39.5s
# | Step time: 1010.5ms
# | Total Cost (Across Horizon): 438.24
# | Cost Height (Across Horizon): 11.15
# | Cost Orientation (Across Horizon): 2.57
# | Velocity (Across Horizon): 421.08
# | Control (Across Horizon): 3.44
#
# Step 15
#
# Torso Position: [0.021  0.     1.3677]
#
# | Total time: 40.5s
# | Step time: 1004.3ms
# | Total Cost (Across Horizon): 441.95
# | Cost Height (Across Horizon): 11.02
# | Cost Orientation (Across Horizon): 3.00
# | Velocity (Across Horizon): 424.44
# | Control (Across Horizon): 3.49
#
# Step 16
#
# Torso Position: [0.0312 0.     1.3755]
#
# | Total time: 41.7s
# | Step time: 1191.7ms
# | Total Cost (Across Horizon): 397.76
# | Cost Height (Across Horizon): 10.77
# | Cost Orientation (Across Horizon): 3.74
# | Velocity (Across Horizon): 379.67
# | Control (Across Horizon): 3.57
#
# Step 17
#
# Torso Position: [0.0363 0.     1.3842]
#
# | Total time: 43.0s
# | Step time: 1293.4ms
# | Total Cost (Across Horizon): 386.84
# | Cost Height (Across Horizon): 11.67
# | Cost Orientation (Across Horizon): 3.31
# | Velocity (Across Horizon): 368.17
# | Control (Across Horizon): 3.70
#
# Step 18
#
# Torso Position: [0.033  0.     1.3992]
#
# | Total time: 44.1s
# | Step time: 1066.1ms
# | Total Cost (Across Horizon): 364.60
# | Cost Height (Across Horizon): 11.06
# | Cost Orientation (Across Horizon): 4.49
# | Velocity (Across Horizon): 345.31
# | Control (Across Horizon): 3.74
#
# Step 19
#
# Torso Position: [0.0273 0.     1.4112]
#
# | Total time: 45.1s
# | Step time: 1021.2ms
# | Total Cost (Across Horizon): 352.90
# | Cost Height (Across Horizon): 9.87
# | Cost Orientation (Across Horizon): 3.44
# | Velocity (Across Horizon): 335.78
# | Control (Across Horizon): 3.81
#
# Step 20
#
# Torso Position: [0.0242 0.     1.4165]
#
# | Total time: 46.1s
# | Step time: 1006.2ms
# | Total Cost (Across Horizon): 384.14
# | Cost Height (Across Horizon): 8.40
# | Cost Orientation (Across Horizon): 3.48
# | Velocity (Across Horizon): 368.39
# | Control (Across Horizon): 3.86
#
# Step 21
#
# Torso Position: [0.0243 0.     1.4141]
#
# | Total time: 47.1s
# | Step time: 1002.1ms
# | Total Cost (Across Horizon): 331.60
# | Cost Height (Across Horizon): 10.20
# | Cost Orientation (Across Horizon): 4.28
# | Velocity (Across Horizon): 313.21
# | Control (Across Horizon): 3.91
#
# Step 22
#
# Torso Position: [0.0255 0.     1.4059]
#
# | Total time: 48.2s
# | Step time: 1018.8ms
# | Total Cost (Across Horizon): 344.91
# | Cost Height (Across Horizon): 9.69
# | Cost Orientation (Across Horizon): 4.86
# | Velocity (Across Horizon): 326.37
# | Control (Across Horizon): 3.99
#
# Step 23
#
# Torso Position: [0.0292 0.     1.3929]
#
# | Total time: 49.2s
# | Step time: 1019.0ms
# | Total Cost (Across Horizon): 342.63
# | Cost Height (Across Horizon): 15.37
# | Cost Orientation (Across Horizon): 5.04
# | Velocity (Across Horizon): 318.26
# | Control (Across Horizon): 3.96
#
# Step 24
#
# Torso Position: [0.0327 0.     1.3779]
#
# | Total time: 50.2s
# | Step time: 1024.3ms
# | Total Cost (Across Horizon): 333.53
# | Cost Height (Across Horizon): 6.23
# | Cost Orientation (Across Horizon): 3.68
# | Velocity (Across Horizon): 319.38
# | Control (Across Horizon): 4.24
#
# Step 25
#
# Torso Position: [0.0369 0.     1.359 ]
#
# | Total time: 51.3s
# | Step time: 1046.7ms
# | Total Cost (Across Horizon): 333.58
# | Cost Height (Across Horizon): 5.60
# | Cost Orientation (Across Horizon): 3.58
# | Velocity (Across Horizon): 319.70
# | Control (Across Horizon): 4.71
#
# Step 26
#
# Torso Position: [0.0417 0.     1.336 ]
#
# | Total time: 52.3s
# | Step time: 1023.9ms
# | Total Cost (Across Horizon): 487.45
# | Cost Height (Across Horizon): 4.24
# | Cost Orientation (Across Horizon): 4.06
# | Velocity (Across Horizon): 474.22
# | Control (Across Horizon): 4.93
#
# Step 27
#
# Torso Position: [0.0474 0.     1.3082]
#
# | Total time: 53.3s
# | Step time: 1017.1ms
# | Total Cost (Across Horizon): 483.27
# | Cost Height (Across Horizon): 3.63
# | Cost Orientation (Across Horizon): 4.24
# | Velocity (Across Horizon): 470.41
# | Control (Across Horizon): 4.99
#
# Step 28
#
# Torso Position: [0.0556 0.     1.2758]
#
# | Total time: 54.5s
# | Step time: 1226.0ms
# | Total Cost (Across Horizon): 557.97
# | Cost Height (Across Horizon): 2.81
# | Cost Orientation (Across Horizon): 6.13
# | Velocity (Across Horizon): 543.82
# | Control (Across Horizon): 5.21
#
# Step 29
#
# Torso Position: [0.0619 0.     1.253 ]
#
# | Total time: 55.8s
# | Step time: 1291.6ms
# | Total Cost (Across Horizon): 502.84
# | Cost Height (Across Horizon): 3.82
# | Cost Orientation (Across Horizon): 5.16
# | Velocity (Across Horizon): 488.64
# | Control (Across Horizon): 5.23
#
# Step 30
#
# Torso Position: [0.0686 0.     1.2342]
#
# | Total time: 56.9s
# | Step time: 1065.8ms
# | Total Cost (Across Horizon): 533.71
# | Cost Height (Across Horizon): 2.89
# | Cost Orientation (Across Horizon): 5.51
# | Velocity (Across Horizon): 519.91
# | Control (Across Horizon): 5.40
#
# Step 31
#
# Torso Position: [0.0713 0.     1.232 ]
#
# | Total time: 57.9s
# | Step time: 1028.2ms
# | Total Cost (Across Horizon): 517.70
# | Cost Height (Across Horizon): 4.24
# | Cost Orientation (Across Horizon): 4.89
# | Velocity (Across Horizon): 503.06
# | Control (Across Horizon): 5.51
#
# Step 32
#
# Torso Position: [0.0752 0.     1.2324]
#
# | Total time: 59.0s
# | Step time: 1034.6ms
# | Total Cost (Across Horizon): 631.52
# | Cost Height (Across Horizon): 2.92
# | Cost Orientation (Across Horizon): 6.46
# | Velocity (Across Horizon): 616.72
# | Control (Across Horizon): 5.42
#
# Step 33
#
# Torso Position: [0.0816 0.     1.2325]
#
# | Total time: 60.0s
# | Step time: 1031.3ms
# | Total Cost (Across Horizon): 565.36
# | Cost Height (Across Horizon): 3.18
# | Cost Orientation (Across Horizon): 4.77
# | Velocity (Across Horizon): 552.03
# | Control (Across Horizon): 5.37
#
# Step 34
#
# Torso Position: [0.0913 0.     1.2245]
#
# | Total time: 61.0s
# | Step time: 1031.1ms
# | Total Cost (Across Horizon): 508.20
# | Cost Height (Across Horizon): 4.05
# | Cost Orientation (Across Horizon): 4.39
# | Velocity (Across Horizon): 494.49
# | Control (Across Horizon): 5.27
#
# Step 35
#
# Torso Position: [0.1032 0.     1.2218]
#
# | Total time: 62.1s
# | Step time: 1027.6ms
# | Total Cost (Across Horizon): 482.10
# | Cost Height (Across Horizon): 6.36
# | Cost Orientation (Across Horizon): 3.25
# | Velocity (Across Horizon): 467.20
# | Control (Across Horizon): 5.29
#
# Step 36
#
# Torso Position: [0.1175 0.     1.2214]
#
# | Total time: 63.1s
# | Step time: 1032.8ms
# | Total Cost (Across Horizon): 490.39
# | Cost Height (Across Horizon): 10.83
# | Cost Orientation (Across Horizon): 3.25
# | Velocity (Across Horizon): 470.99
# | Control (Across Horizon): 5.32
#
# Step 37
#
# Torso Position: [0.1319 0.     1.2211]
#
# | Total time: 64.1s
# | Step time: 1051.6ms
# | Total Cost (Across Horizon): 467.59
# | Cost Height (Across Horizon): 11.19
# | Cost Orientation (Across Horizon): 3.29
# | Velocity (Across Horizon): 447.59
# | Control (Across Horizon): 5.51
#
# Step 38
#
# Torso Position: [0.1434 0.     1.2278]
#
# | Total time: 65.2s
# | Step time: 1054.8ms
# | Total Cost (Across Horizon): 466.46
# | Cost Height (Across Horizon): 15.39
# | Cost Orientation (Across Horizon): 2.69
# | Velocity (Across Horizon): 442.78
# | Control (Across Horizon): 5.60
#
# Step 39
#
# Torso Position: [0.1538 0.     1.2379]
#
# | Total time: 66.2s
# | Step time: 1029.1ms
# | Total Cost (Across Horizon): 464.16
# | Cost Height (Across Horizon): 30.45
# | Cost Orientation (Across Horizon): 3.63
# | Velocity (Across Horizon): 424.19
# | Control (Across Horizon): 5.90
#
# Step 40
#
# Torso Position: [0.1673 0.     1.2423]
#
# | Total time: 67.6s
# | Step time: 1314.3ms
# | Total Cost (Across Horizon): 458.91
# | Cost Height (Across Horizon): 10.91
# | Cost Orientation (Across Horizon): 2.06
# | Velocity (Across Horizon): 440.07
# | Control (Across Horizon): 5.87
#
# Step 41
#
# Torso Position: [0.1794 0.     1.2548]
#
# | Total time: 68.8s
# | Step time: 1291.3ms
# | Total Cost (Across Horizon): 472.34
# | Cost Height (Across Horizon): 8.41
# | Cost Orientation (Across Horizon): 2.04
# | Velocity (Across Horizon): 456.07
# | Control (Across Horizon): 5.82
#
# Step 42
#
# Torso Position: [0.193  0.     1.2673]
#
# | Total time: 69.9s
# | Step time: 1057.4ms
# | Total Cost (Across Horizon): 414.79
# | Cost Height (Across Horizon): 21.21
# | Cost Orientation (Across Horizon): 1.58
# | Velocity (Across Horizon): 386.35
# | Control (Across Horizon): 5.66
#
# Step 43
#
# Torso Position: [0.2077 0.     1.2798]
#
# | Total time: 70.9s
# | Step time: 1018.3ms
# | Total Cost (Across Horizon): 393.89
# | Cost Height (Across Horizon): 15.92
# | Cost Orientation (Across Horizon): 1.49
# | Velocity (Across Horizon): 370.68
# | Control (Across Horizon): 5.80
#
# Step 44
#
# Torso Position: [0.2237 0.     1.2923]
#
# | Total time: 71.9s
# | Step time: 1017.1ms
# | Total Cost (Across Horizon): 383.21
# | Cost Height (Across Horizon): 10.78
# | Cost Orientation (Across Horizon): 1.93
# | Velocity (Across Horizon): 364.55
# | Control (Across Horizon): 5.94
#
# Step 45
#
# Torso Position: [0.2343 0.     1.2981]
#
# | Total time: 73.0s
# | Step time: 1001.3ms
# | Total Cost (Across Horizon): 349.03
# | Cost Height (Across Horizon): 19.38
# | Cost Orientation (Across Horizon): 1.60
# | Velocity (Across Horizon): 321.91
# | Control (Across Horizon): 6.15
#
# Step 46
#
# Torso Position: [0.2431 0.     1.2977]
#
# | Total time: 74.0s
# | Step time: 1009.3ms
# | Total Cost (Across Horizon): 334.15
# | Cost Height (Across Horizon): 19.46
# | Cost Orientation (Across Horizon): 1.65
# | Velocity (Across Horizon): 306.97
# | Control (Across Horizon): 6.07
#
# Step 47
#
# Torso Position: [0.2522 0.     1.2964]
#
# | Total time: 75.0s
# | Step time: 999.2ms
# | Total Cost (Across Horizon): 320.21
# | Cost Height (Across Horizon): 21.65
# | Cost Orientation (Across Horizon): 2.17
# | Velocity (Across Horizon): 290.51
# | Control (Across Horizon): 5.88
#
# Step 48
#
# Torso Position: [0.2617 0.     1.2984]
#
# | Total time: 76.0s
# | Step time: 1003.1ms
# | Total Cost (Across Horizon): 300.99
# | Cost Height (Across Horizon): 20.23
# | Cost Orientation (Across Horizon): 2.78
# | Velocity (Across Horizon): 271.94
# | Control (Across Horizon): 6.04
#
# Step 49
#
# Torso Position: [0.2719 0.     1.3014]
#
# | Total time: 77.0s
# | Step time: 1003.8ms
# | Total Cost (Across Horizon): 286.36
# | Cost Height (Across Horizon): 33.93
# | Cost Orientation (Across Horizon): 1.06
# | Velocity (Across Horizon): 245.39
# | Control (Across Horizon): 5.98
#
# Step 50
#
# Torso Position: [0.282  0.     1.3035]
#
# | Total time: 78.0s
# | Step time: 998.8ms
# | Total Cost (Across Horizon): 280.86
# | Cost Height (Across Horizon): 43.19
# | Cost Orientation (Across Horizon): 1.58
# | Velocity (Across Horizon): 230.11
# | Control (Across Horizon): 5.99
#
# Step 51
#
# Torso Position: [0.2923 0.     1.3039]
#
# | Total time: 79.0s
# | Step time: 1004.1ms
# | Total Cost (Across Horizon): 275.37
# | Cost Height (Across Horizon): 43.26
# | Cost Orientation (Across Horizon): 1.34
# | Velocity (Across Horizon): 224.73
# | Control (Across Horizon): 6.04
#
# Step 52
#
# Torso Position: [0.3025 0.     1.3034]
#
# | Total time: 80.2s
# | Step time: 1247.2ms
# | Total Cost (Across Horizon): 270.73
# | Cost Height (Across Horizon): 46.24
# | Cost Orientation (Across Horizon): 1.41
# | Velocity (Across Horizon): 216.98
# | Control (Across Horizon): 6.10
#
# Step 53
#
# Torso Position: [0.3124 0.     1.3044]
#
# | Total time: 81.5s
# | Step time: 1267.6ms
# | Total Cost (Across Horizon): 262.11
# | Cost Height (Across Horizon): 53.67
# | Cost Orientation (Across Horizon): 1.15
# | Velocity (Across Horizon): 201.07
# | Control (Across Horizon): 6.23
#
# Step 54
#
# Torso Position: [0.3226 0.     1.3051]
#
# | Total time: 82.6s
# | Step time: 1078.7ms
# | Total Cost (Across Horizon): 285.70
# | Cost Height (Across Horizon): 57.81
# | Cost Orientation (Across Horizon): 1.24
# | Velocity (Across Horizon): 220.52
# | Control (Across Horizon): 6.14
#
# Step 55
#
# Torso Position: [0.333  0.     1.3056]
#
# | Total time: 83.6s
# | Step time: 1013.3ms
# | Total Cost (Across Horizon): 297.55
# | Cost Height (Across Horizon): 71.46
# | Cost Orientation (Across Horizon): 6.09
# | Velocity (Across Horizon): 213.79
# | Control (Across Horizon): 6.21
#
# Step 56
#
# Torso Position: [0.3435 0.     1.3061]
#
# | Total time: 84.6s
# | Step time: 1008.8ms
# | Total Cost (Across Horizon): 358.10
# | Cost Height (Across Horizon): 85.25
# | Cost Orientation (Across Horizon): 8.63
# | Velocity (Across Horizon): 257.94
# | Control (Across Horizon): 6.28
#
# Step 57
#
# Torso Position: [0.3542 0.     1.3066]
#
# | Total time: 85.6s
# | Step time: 1031.2ms
# | Total Cost (Across Horizon): 418.39
# | Cost Height (Across Horizon): 90.31
# | Cost Orientation (Across Horizon): 12.93
# | Velocity (Across Horizon): 308.99
# | Control (Across Horizon): 6.16
#
# Step 58
#
# Torso Position: [0.3654 0.     1.3069]
#
# | Total time: 86.7s
# | Step time: 1009.2ms
# | Total Cost (Across Horizon): 379.91
# | Cost Height (Across Horizon): 83.64
# | Cost Orientation (Across Horizon): 23.89
# | Velocity (Across Horizon): 266.33
# | Control (Across Horizon): 6.05
#
# Step 59
#
# Torso Position: [0.3769 0.     1.3072]
#
# | Total time: 87.7s
# | Step time: 1007.5ms
# | Total Cost (Across Horizon): 423.97
# | Cost Height (Across Horizon): 107.05
# | Cost Orientation (Across Horizon): 9.00
# | Velocity (Across Horizon): 301.86
# | Control (Across Horizon): 6.07
#
# Step 60
#
# Torso Position: [0.3883 0.     1.3074]
#
# | Total time: 88.7s
# | Step time: 1007.5ms
# | Total Cost (Across Horizon): 477.61
# | Cost Height (Across Horizon): 107.44
# | Cost Orientation (Across Horizon): 8.69
# | Velocity (Across Horizon): 355.40
# | Control (Across Horizon): 6.09
#
# Step 61
#
# Torso Position: [0.3998 0.     1.3075]
#
# | Total time: 89.7s
# | Step time: 1004.1ms
# | Total Cost (Across Horizon): 473.96
# | Cost Height (Across Horizon): 119.03
# | Cost Orientation (Across Horizon): 10.13
# | Velocity (Across Horizon): 338.73
# | Control (Across Horizon): 6.06
#
# Step 62
#
# Torso Position: [0.4115 0.     1.3075]
#
# | Total time: 90.7s
# | Step time: 1009.0ms
# | Total Cost (Across Horizon): 403.40
# | Cost Height (Across Horizon): 62.63
# | Cost Orientation (Across Horizon): 18.74
# | Velocity (Across Horizon): 316.07
# | Control (Across Horizon): 5.96
#
# Step 63
#
# Torso Position: [0.4234 0.     1.3074]
#
# | Total time: 91.7s
# | Step time: 1010.6ms
# | Total Cost (Across Horizon): 668.29
# | Cost Height (Across Horizon): 117.03
# | Cost Orientation (Across Horizon): 23.64
# | Velocity (Across Horizon): 521.74
# | Control (Across Horizon): 5.89
#
# Step 64
#
# Torso Position: [0.4355 0.     1.3073]
#
# | Total time: 93.0s
# | Step time: 1309.4ms
# | Total Cost (Across Horizon): 643.67
# | Cost Height (Across Horizon): 137.18
# | Cost Orientation (Across Horizon): 17.75
# | Velocity (Across Horizon): 483.04
# | Control (Across Horizon): 5.71
#
# Step 65
#
# Torso Position: [0.4484 0.     1.3069]
#
# | Total time: 94.3s
# | Step time: 1275.2ms
# | Total Cost (Across Horizon): 617.17
# | Cost Height (Across Horizon): 155.02
# | Cost Orientation (Across Horizon): 15.79
# | Velocity (Across Horizon): 440.81
# | Control (Across Horizon): 5.55
#
# Step 66
#
# Torso Position: [0.4633 0.     1.3062]
#
# | Total time: 95.4s
# | Step time: 1088.4ms
# | Total Cost (Across Horizon): 623.69
# | Cost Height (Across Horizon): 143.97
# | Cost Orientation (Across Horizon): 15.06
# | Velocity (Across Horizon): 459.14
# | Control (Across Horizon): 5.52
#
# Step 67
#
# Torso Position: [0.4819 0.     1.3049]
#
# | Total time: 96.4s
# | Step time: 1016.8ms
# | Total Cost (Across Horizon): 563.95
# | Cost Height (Across Horizon): 114.09
# | Cost Orientation (Across Horizon): 29.68
# | Velocity (Across Horizon): 414.66
# | Control (Across Horizon): 5.53
#
# Step 68
#
# Torso Position: [0.5037 0.     1.3019]
#
# | Total time: 97.4s
# | Step time: 1020.2ms
# | Total Cost (Across Horizon): 484.66
# | Cost Height (Across Horizon): 115.89
# | Cost Orientation (Across Horizon): 32.31
# | Velocity (Across Horizon): 331.00
# | Control (Across Horizon): 5.45
#
# Step 69
#
# Torso Position: [0.5274 0.     1.3002]
#
# | Total time: 98.4s
# | Step time: 1007.8ms
# | Total Cost (Across Horizon): 618.60
# | Cost Height (Across Horizon): 127.32
# | Cost Orientation (Across Horizon): 37.22
# | Velocity (Across Horizon): 448.75
# | Control (Across Horizon): 5.31
#
# Step 70
#
# Torso Position: [0.5527 0.     1.2981]
#
# | Total time: 99.4s
# | Step time: 999.9ms
# | Total Cost (Across Horizon): 542.65
# | Cost Height (Across Horizon): 148.50
# | Cost Orientation (Across Horizon): 34.96
# | Velocity (Across Horizon): 353.91
# | Control (Across Horizon): 5.27
#
# Step 71
#
# Torso Position: [0.5794 0.     1.2949]
#
# | Total time: 100.5s
# | Step time: 1001.1ms
# | Total Cost (Across Horizon): 659.02
# | Cost Height (Across Horizon): 134.86
# | Cost Orientation (Across Horizon): 45.44
# | Velocity (Across Horizon): 473.32
# | Control (Across Horizon): 5.41
#
# Step 72
#
# Torso Position: [0.6075 0.     1.2907]
#
# | Total time: 101.5s
# | Step time: 1017.4ms
# | Total Cost (Across Horizon): 648.40
# | Cost Height (Across Horizon): 114.42
# | Cost Orientation (Across Horizon): 53.01
# | Velocity (Across Horizon): 475.50
# | Control (Across Horizon): 5.47
#
# Step 73
#
# Torso Position: [0.6371 0.     1.2854]
#
# | Total time: 102.5s
# | Step time: 1016.3ms
# | Total Cost (Across Horizon): 688.23
# | Cost Height (Across Horizon): 120.87
# | Cost Orientation (Across Horizon): 64.97
# | Velocity (Across Horizon): 497.05
# | Control (Across Horizon): 5.34
#
# Step 74
#
# Torso Position: [0.6681 0.     1.2791]
#
# | Total time: 103.5s
# | Step time: 1004.6ms
# | Total Cost (Across Horizon): 493.90
# | Cost Height (Across Horizon): 74.62
# | Cost Orientation (Across Horizon): 69.90
# | Velocity (Across Horizon): 343.82
# | Control (Across Horizon): 5.55
#
# Step 75
#
# Torso Position: [0.7006 0.     1.2715]
#
# | Total time: 104.5s
# | Step time: 1027.5ms
# | Total Cost (Across Horizon): 446.94
# | Cost Height (Across Horizon): 60.53
# | Cost Orientation (Across Horizon): 103.77
# | Velocity (Across Horizon): 277.23
# | Control (Across Horizon): 5.42
#
# Step 76
#
# Torso Position: [0.7347 0.     1.2625]
#
# | Total time: 105.9s
# | Step time: 1328.2ms
# | Total Cost (Across Horizon): 559.39
# | Cost Height (Across Horizon): 100.28
# | Cost Orientation (Across Horizon): 54.61
# | Velocity (Across Horizon): 399.25
# | Control (Across Horizon): 5.25
#
# Step 77
#
# Torso Position: [0.7705 0.     1.2519]
#
# | Total time: 107.1s
# | Step time: 1249.4ms
# | Total Cost (Across Horizon): 466.31
# | Cost Height (Across Horizon): 73.68
# | Cost Orientation (Across Horizon): 26.92
# | Velocity (Across Horizon): 360.41
# | Control (Across Horizon): 5.30
#
# Step 78
#
# Torso Position: [0.808  0.     1.2396]
#
# | Total time: 108.1s
# | Step time: 1031.0ms
# | Total Cost (Across Horizon): 698.54
# | Cost Height (Across Horizon): 127.98
# | Cost Orientation (Across Horizon): 46.31
# | Velocity (Across Horizon): 519.15
# | Control (Across Horizon): 5.09
#
# Step 79
#
# Torso Position: [0.8475 0.     1.2252]
#
# | Total time: 109.2s
# | Step time: 1012.4ms
# | Total Cost (Across Horizon): 765.73
# | Cost Height (Across Horizon): 139.42
# | Cost Orientation (Across Horizon): 41.07
# | Velocity (Across Horizon): 580.03
# | Control (Across Horizon): 5.20
#
# Step 80
#
# Torso Position: [0.8892 0.     1.2085]
#
# | Total time: 110.2s
# | Step time: 1019.3ms
# | Total Cost (Across Horizon): 732.63
# | Cost Height (Across Horizon): 140.92
# | Cost Orientation (Across Horizon): 43.53
# | Velocity (Across Horizon): 543.07
# | Control (Across Horizon): 5.12
#
# Step 81
#
# Torso Position: [0.9328 0.     1.1891]
#
# | Total time: 111.2s
# | Step time: 1006.8ms
# | Total Cost (Across Horizon): 764.94
# | Cost Height (Across Horizon): 99.86
# | Cost Orientation (Across Horizon): 56.67
# | Velocity (Across Horizon): 603.36
# | Control (Across Horizon): 5.05
#
# Step 82
#
# Torso Position: [0.9785 0.     1.1665]
#
# | Total time: 112.2s
# | Step time: 1021.0ms
# | Total Cost (Across Horizon): 616.61
# | Cost Height (Across Horizon): 128.80
# | Cost Orientation (Across Horizon): 43.67
# | Velocity (Across Horizon): 439.09
# | Control (Across Horizon): 5.05
#
# Step 83
#
# Torso Position: [0.9948 0.     1.1699]
#
# | Total time: 113.2s
# | Step time: 1029.2ms
# | Total Cost (Across Horizon): 655.67
# | Cost Height (Across Horizon): 88.88
# | Cost Orientation (Across Horizon): 52.13
# | Velocity (Across Horizon): 509.59
# | Control (Across Horizon): 5.06
#
# Step 84
#
# Torso Position: [1.0063 0.     1.1738]
#
# | Total time: 114.3s
# | Step time: 1021.1ms
# | Total Cost (Across Horizon): 713.38
# | Cost Height (Across Horizon): 130.57
# | Cost Orientation (Across Horizon): 41.88
# | Velocity (Across Horizon): 535.69
# | Control (Across Horizon): 5.24
#
# Step 85
#
# Torso Position: [1.0157 0.     1.1757]
#
# | Total time: 115.3s
# | Step time: 1009.3ms
# | Total Cost (Across Horizon): 757.84
# | Cost Height (Across Horizon): 90.71
# | Cost Orientation (Across Horizon): 67.22
# | Velocity (Across Horizon): 594.77
# | Control (Across Horizon): 5.14
#
# Step 86
#
# Torso Position: [1.024  0.     1.1743]
#
# | Total time: 116.3s
# | Step time: 1013.3ms
# | Total Cost (Across Horizon): 672.79
# | Cost Height (Across Horizon): 81.35
# | Cost Orientation (Across Horizon): 67.31
# | Velocity (Across Horizon): 518.96
# | Control (Across Horizon): 5.16
#
# Step 87
#
# Torso Position: [1.0322 0.     1.1687]
#
# | Total time: 117.4s
# | Step time: 1111.8ms
# | Total Cost (Across Horizon): 687.64
# | Cost Height (Across Horizon): 39.42
# | Cost Orientation (Across Horizon): 74.20
# | Velocity (Across Horizon): 568.97
# | Control (Across Horizon): 5.06
#
# Step 88
#
# Torso Position: [1.0404 0.     1.1593]
#
# | Total time: 118.7s
# | Step time: 1328.0ms
# | Total Cost (Across Horizon): 865.73
# | Cost Height (Across Horizon): 58.03
# | Cost Orientation (Across Horizon): 100.27
# | Velocity (Across Horizon): 702.54
# | Control (Across Horizon): 4.89
#
# Step 89
#
# Torso Position: [1.054 0.    1.154]
#
# | Total time: 120.1s
# | Step time: 1325.8ms
# | Total Cost (Across Horizon): 873.82
# | Cost Height (Across Horizon): 82.28
# | Cost Orientation (Across Horizon): 92.09
# | Velocity (Across Horizon): 694.22
# | Control (Across Horizon): 5.23
#
# Step 90
#
# Torso Position: [1.0706 0.     1.1488]
#
# | Total time: 121.1s
# | Step time: 1011.5ms
# | Total Cost (Across Horizon): 888.45
# | Cost Height (Across Horizon): 68.29
# | Cost Orientation (Across Horizon): 129.62
# | Velocity (Across Horizon): 685.30
# | Control (Across Horizon): 5.24
#
# Step 91
#
# Torso Position: [1.0881 0.     1.139 ]
#
# | Total time: 122.1s
# | Step time: 999.6ms
# | Total Cost (Across Horizon): 932.80
# | Cost Height (Across Horizon): 121.04
# | Cost Orientation (Across Horizon): 79.51
# | Velocity (Across Horizon): 726.95
# | Control (Across Horizon): 5.30
#
# Step 92
#
# Torso Position: [1.1067 0.     1.1252]
#
# | Total time: 123.1s
# | Step time: 1018.7ms
# | Total Cost (Across Horizon): 929.93
# | Cost Height (Across Horizon): 125.05
# | Cost Orientation (Across Horizon): 87.01
# | Velocity (Across Horizon): 712.44
# | Control (Across Horizon): 5.43
#
# Step 93
#
# Torso Position: [1.1283 0.     1.1099]
#
# | Total time: 124.1s
# | Step time: 1011.8ms
# | Total Cost (Across Horizon): 984.75
# | Cost Height (Across Horizon): 112.70
# | Cost Orientation (Across Horizon): 108.29
# | Velocity (Across Horizon): 758.37
# | Control (Across Horizon): 5.38
#
# Step 94
#
# Torso Position: [1.1526 0.     1.0927]
#
# | Total time: 125.1s
# | Step time: 1007.2ms
# | Total Cost (Across Horizon): 1020.21
# | Cost Height (Across Horizon): 118.84
# | Cost Orientation (Across Horizon): 149.18
# | Velocity (Across Horizon): 746.66
# | Control (Across Horizon): 5.54
#
# Step 95
#
# Torso Position: [1.1778 0.     1.0717]
#
# | Total time: 126.1s
# | Step time: 1005.3ms
# | Total Cost (Across Horizon): 1144.82
# | Cost Height (Across Horizon): 81.41
# | Cost Orientation (Across Horizon): 155.45
# | Velocity (Across Horizon): 902.65
# | Control (Across Horizon): 5.31
#
# Step 96
#
# Torso Position: [1.2    0.     1.0524]
#
# | Total time: 127.2s
# | Step time: 1009.5ms
# | Total Cost (Across Horizon): 1029.85
# | Cost Height (Across Horizon): 128.75
# | Cost Orientation (Across Horizon): 131.98
# | Velocity (Across Horizon): 763.87
# | Control (Across Horizon): 5.25
#
# Step 97
#
# Torso Position: [1.2193 0.     1.0347]
#
# | Total time: 128.2s
# | Step time: 1017.2ms
# | Total Cost (Across Horizon): 1135.37
# | Cost Height (Across Horizon): 40.20
# | Cost Orientation (Across Horizon): 349.13
# | Velocity (Across Horizon): 740.72
# | Control (Across Horizon): 5.32
#
# Step 98
#
# Torso Position: [1.2362 0.     1.0158]
#
# | Total time: 129.2s
# | Step time: 1001.6ms
# | Total Cost (Across Horizon): 1121.63
# | Cost Height (Across Horizon): 38.65
# | Cost Orientation (Across Horizon): 362.72
# | Velocity (Across Horizon): 714.72
# | Control (Across Horizon): 5.54
#
# Step 99
#
# Torso Position: [1.2489 0.     1.0184]
#
# | Total time: 130.4s
# | Step time: 1172.3ms
# | Total Cost (Across Horizon): 1207.35
# | Cost Height (Across Horizon): 38.43
# | Cost Orientation (Across Horizon): 418.77
# | Velocity (Across Horizon): 744.55
# | Control (Across Horizon): 5.60
# /usr/lib/python3.10/subprocess.py:1796: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _posixsubprocess.fork_exec(
#
# Video saved: walker_video.mp4

# %%
from IPython.display import Video
Video("walker_video.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
