# %% [markdown]
# <a href="https://colab.research.google.com/github/alinjar1996/tutorial_cem/blob/main/tutorial_biped.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update
# !sudo apt-get install python3.10 python3.10-venv python3.10-distutils

# %%
# !python3.10 -m venv py310_env

# %%
# !py310_env/bin/python -m ensurepip
# !py310_env/bin/pip install pip==22.0.2

# %%
# !py310_env/bin/python --version
# !py310_env/bin/pip --version

# %%
# !git clone https://github.com/alinjar1996/sampling_based_general.git -b issue_1_biped_torque

# %%
# %cd /content/sampling_based_general
# !git pull
# Out:
# /content/sampling_based_general
# Already up to date.

# %%
# !ls /content
# !/content/py310_env/bin/pip install -r requirements.txt

# %%
# %cd /content/sampling_based_general/real_demo

# !git clone https://github.com/AKS-Lab-Univertsity-of-Tartu/math_utils_aks_lab.git math_utils

# %%
# %cd /content/sampling_based_general
# Out:
# /content/sampling_based_general

# %%
# !apt-get update
# !apt-get install -y libgl1-mesa-dev libegl1-mesa-dev

# %%
# !/content/py310_env/bin/pip install imageio[ffmpeg]

# %%
# !python3 -u real_demo/pendulum_demo_pyt_colab.py
# !/content/py310_env/bin/python3.10 real_demo/pendulum_demo_pyt_colab.py --num_batch 500 --maxiter_cem 1 --steps 100
# !/content/py310_env/bin/python3.10 \
    real_demo/walker_demo_pyt_colab.py \
    --num_batch 200 \
    --maxiter_cem 1 \
    --steps 30 \
    --timestep 0.05 \
    --maxiter_projection 5 \
    --num_steps 10
# Out:
# Sensors: 0 1 2
#
# Torque-controlled joints:
#   0: 'rootz' -> controlled: False
#   1: 'rootx' -> controlled: False
#   2: 'rooty' -> controlled: False
#   3: 'right_hip' -> controlled: True
#   4: 'right_knee' -> controlled: True
#   5: 'right_ankle' -> controlled: True
#   6: 'left_hip' -> controlled: True
#   7: 'left_knee' -> controlled: True
#   8: 'left_ankle' -> controlled: True
#
#  Default backend: cpu
#  Timestep: 0.05
#  CEM Iter: 1
#  Projection Iter: 5
#  Number of batches: 200
#  Number of steps per trajectory: 10
#  Time per trajectory: 0.5
#  Number of variables: 24
#  Number of Total constraints: 360
#
# Step 0
#
# Torso Position: [0.  0.  1.3]
#
# | Total time: 32.7s
# | Step time: 32677.8ms
# | Cost: 255.46
# | Height: 3.89
# | Orientation: 27.44
# | Velocity: 223.13
# | Control: 1.00
#
# Step 1
#
# Torso Position: [-0.      0.      1.2755]
#
# | Total time: 33.2s
# | Step time: 522.0ms
# | Cost: 237.58
# | Height: 1.21
# | Orientation: 7.78
# | Velocity: 227.71
# | Control: 0.88
#
# Step 2
#
# Torso Position: [-0.0101  0.      1.2825]
#
# | Total time: 33.7s
# | Step time: 457.4ms
# | Cost: 226.98
# | Height: 0.56
# | Orientation: 6.45
# | Velocity: 218.89
# | Control: 1.08
#
# Step 3
#
# Torso Position: [-0.0286  0.      1.2849]
#
# | Total time: 34.2s
# | Step time: 475.9ms
# | Cost: 254.28
# | Height: 0.85
# | Orientation: 3.35
# | Velocity: 249.57
# | Control: 0.51
#
# Step 4
#
# Torso Position: [-0.0325  0.      1.2754]
#
# | Total time: 34.6s
# | Step time: 444.3ms
# | Cost: 225.72
# | Height: 1.06
# | Orientation: 7.89
# | Velocity: 216.13
# | Control: 0.65
#
# Step 5
#
# Torso Position: [-0.0385  0.      1.2713]
#
# | Total time: 35.1s
# | Step time: 459.5ms
# | Cost: 211.49
# | Height: 0.51
# | Orientation: 5.25
# | Velocity: 205.06
# | Control: 0.67
#
# Step 6
#
# Torso Position: [-0.045   0.      1.2709]
#
# | Total time: 35.5s
# | Step time: 453.5ms
# | Cost: 227.65
# | Height: 0.33
# | Orientation: 5.93
# | Velocity: 220.53
# | Control: 0.86
#
# Step 7
#
# Torso Position: [-0.0505  0.      1.2622]
#
# | Total time: 36.0s
# | Step time: 450.5ms
# | Cost: 174.34
# | Height: 1.52
# | Orientation: 12.00
# | Velocity: 159.79
# | Control: 1.02
#
# Step 8
#
# Torso Position: [-0.0574  0.      1.2583]
#
# | Total time: 36.5s
# | Step time: 476.5ms
# | Cost: 151.59
# | Height: 1.48
# | Orientation: 9.84
# | Velocity: 139.22
# | Control: 1.06
#
# Step 9
#
# Torso Position: [-0.0642  0.      1.2517]
#
# | Total time: 36.9s
# | Step time: 450.9ms
# | Cost: 125.80
# | Height: 0.94
# | Orientation: 6.97
# | Velocity: 116.86
# | Control: 1.04
#
# Step 10
#
# Torso Position: [-0.0704  0.      1.244 ]
#
# | Total time: 37.4s
# | Step time: 461.9ms
# | Cost: 103.11
# | Height: 0.18
# | Orientation: 4.98
# | Velocity: 96.85
# | Control: 1.10
#
# Step 11
#
# Torso Position: [-0.0757  0.      1.238 ]
#
# | Total time: 37.8s
# | Step time: 449.7ms
# | Cost: 81.43
# | Height: 0.21
# | Orientation: 4.00
# | Velocity: 76.06
# | Control: 1.16
#
# Step 12
#
# Torso Position: [-0.077   0.      1.2357]
#
# | Total time: 38.3s
# | Step time: 485.2ms
# | Cost: 67.01
# | Height: 0.15
# | Orientation: 3.00
# | Velocity: 62.17
# | Control: 1.69
#
# Step 13
#
# Torso Position: [-0.0724  0.      1.235 ]
#
# | Total time: 38.8s
# | Step time: 486.7ms
# | Cost: 56.89
# | Height: 0.56
# | Orientation: 4.04
# | Velocity: 51.27
# | Control: 1.01
#
# Step 14
#
# Torso Position: [-0.0544  0.      1.2365]
#
# | Total time: 39.4s
# | Step time: 555.7ms
# | Cost: 45.90
# | Height: 0.80
# | Orientation: 3.00
# | Velocity: 40.82
# | Control: 1.28
#
# Step 15
#
# Torso Position: [-0.0157  0.      1.2358]
#
# | Total time: 40.2s
# | Step time: 805.9ms
# | Cost: 50.43
# | Height: 2.39
# | Orientation: 6.33
# | Velocity: 40.68
# | Control: 1.02
#
# Step 16
#
# Torso Position: [0.0444 0.     1.2323]
#
# | Total time: 41.0s
# | Step time: 788.5ms
# | Cost: 52.08
# | Height: 5.82
# | Orientation: 10.48
# | Velocity: 34.60
# | Control: 1.18
#
# Step 17
#
# Torso Position: [0.1283 0.     1.2178]
#
# | Total time: 41.7s
# | Step time: 752.7ms
# | Cost: 66.44
# | Height: 10.31
# | Orientation: 17.19
# | Velocity: 38.17
# | Control: 0.77
#
# Step 18
#
# Torso Position: [0.2301 0.     1.2022]
#
# | Total time: 42.5s
# | Step time: 772.6ms
# | Cost: 77.89
# | Height: 18.89
# | Orientation: 27.22
# | Velocity: 30.84
# | Control: 0.94
#
# Step 19
#
# Torso Position: [0.3532 0.     1.1764]
#
# | Total time: 43.0s
# | Step time: 551.5ms
# | Cost: 118.45
# | Height: 29.71
# | Orientation: 27.46
# | Velocity: 60.16
# | Control: 1.11
#
# Step 20
#
# Torso Position: [0.448  0.     1.1623]
#
# | Total time: 43.5s
# | Step time: 452.2ms
# | Cost: 215.74
# | Height: 39.30
# | Orientation: 60.99
# | Velocity: 114.55
# | Control: 0.89
#
# Step 21
#
# Torso Position: [0.4998 0.     1.1263]
#
# | Total time: 44.0s
# | Step time: 475.7ms
# | Cost: 275.44
# | Height: 76.32
# | Orientation: 79.99
# | Velocity: 118.25
# | Control: 0.88
#
# Step 22
#
# Torso Position: [0.5362 0.     1.0768]
#
# | Total time: 44.4s
# | Step time: 456.4ms
# | Cost: 472.41
# | Height: 99.09
# | Orientation: 94.16
# | Velocity: 278.31
# | Control: 0.84
#
# Step 23
#
# Torso Position: [0.5629 0.     1.0037]
#
# | Total time: 44.9s
# | Step time: 469.3ms
# | Cost: 534.41
# | Height: 121.27
# | Orientation: 117.99
# | Velocity: 294.30
# | Control: 0.86
#
# Step 24
#
# Torso Position: [0.5923 0.     0.9046]
#
# | Total time: 45.3s
# | Step time: 440.5ms
# | Cost: 608.22
# | Height: 140.01
# | Orientation: 131.66
# | Velocity: 335.66
# | Control: 0.89
#
# Step 25
#
# Torso Position: [0.6244 0.     0.7797]
#
# | Total time: 45.8s
# | Step time: 470.4ms
# | Cost: 662.95
# | Height: 163.33
# | Orientation: 157.57
# | Velocity: 341.31
# | Control: 0.74
#
# Step 26
#
# Torso Position: [0.6597 0.     0.6306]
#
# | Total time: 46.3s
# | Step time: 452.2ms
# | Cost: 771.90
# | Height: 186.38
# | Orientation: 170.78
# | Velocity: 413.86
# | Control: 0.88
#
# Step 27
#
# Torso Position: [0.7063 0.     0.4692]
#
# | Total time: 46.7s
# | Step time: 456.4ms
# | Cost: 835.32
# | Height: 201.36
# | Orientation: 181.66
# | Velocity: 451.52
# | Control: 0.78
#
# Step 28
#
# Torso Position: [0.7573 0.     0.294 ]
#
# | Total time: 47.2s
# | Step time: 478.3ms
# | Cost: 886.23
# | Height: 214.74
# | Orientation: 192.13
# | Velocity: 478.46
# | Control: 0.90
#
# Step 29
#
# Torso Position: [0.704  0.     0.1973]
#
# | Total time: 47.7s
# | Step time: 451.1ms
# | Cost: 971.85
# | Height: 217.93
# | Orientation: 210.11
# | Velocity: 543.06
# | Control: 0.75
# /usr/lib/python3.10/subprocess.py:1796: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _posixsubprocess.fork_exec(
#
# Video saved: walker_video.mp4

# %%
from IPython.display import Video
Video("walker_video.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
