# %% [markdown]
# <a href="https://colab.research.google.com/github/alinjar1996/tutorial_cem/blob/main/tutorial_biped.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update
# !sudo apt-get install python3.10 python3.10-venv python3.10-distutils
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cli.github.com/packages stable/main amd64 Packages [357 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,388 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.2 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,922 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:16 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [39.2 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,780 kB]
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,813 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,877 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,301 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,652 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,120 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,613 kB]
# Fetched 40.0 MB in 3s (12.7 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.10-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# python3-distutils set to manually installed.
# python3.10 is already the newest version (3.10.12-1~22.04.14).
# python3.10 set to manually installed.
# The following NEW packages will be installed:
#   python3-pip-whl python3-setuptools-whl python3.10-venv
# 0 upgraded, 3 newly installed, 0 to remove and 98 not upgraded.
# Need to get 2,481 kB of archives.
# After this operation, 2,754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.7 [1,683 kB]
# Get:2 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 python3-setuptools-whl all 68.1.2-2~jammy3 [792 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3.10-venv amd64 3.10.12-1~22.04.14 [5,724 B]
# Fetched 2,481 kB in 2s (997 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python3-pip-whl.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../python3-pip-whl_22.0.2+dfsg-1ubuntu0.7_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.7) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../python3-setuptools-whl_68.1.2-2~jammy3_all.deb ...
# Unpacking python3-setuptools-whl (68.1.2-2~jammy3) ...
# Selecting previously unselected package python3.10-venv.
# Preparing to unpack .../python3.10-venv_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking python3.10-venv (3.10.12-1~22.04.14) ...
# Setting up python3-setuptools-whl (68.1.2-2~jammy3) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.7) ...
# Setting up python3.10-venv (3.10.12-1~22.04.14) ...

# %%
# !python3.10 -m venv py310_env

# %%
# !py310_env/bin/python -m ensurepip
# !py310_env/bin/pip install pip==22.0.2
# Out:
# Looking in links: /tmp/tmp3a06fmrm
# Requirement already satisfied: setuptools in ./py310_env/lib/python3.10/site-packages (68.1.2)
# Requirement already satisfied: pip in ./py310_env/lib/python3.10/site-packages (22.0.2)
# Requirement already satisfied: pip==22.0.2 in ./py310_env/lib/python3.10/site-packages (22.0.2)

# %%
# !py310_env/bin/python --version
# !py310_env/bin/pip --version
# Out:
# Python 3.10.12
# pip 22.0.2 from /content/py310_env/lib/python3.10/site-packages/pip (python 3.10)

# %%
# !git clone https://github.com/alinjar1996/sampling_based_general.git -b issue_1_biped_torque
# Out:
# Cloning into 'sampling_based_general'...
# remote: Enumerating objects: 3914, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 3914 (delta 95), reused 100 (delta 50), pack-reused 3759 (from 2)
# Receiving objects: 100% (3914/3914), 573.78 MiB | 31.30 MiB/s, done.
# Resolving deltas: 100% (1945/1945), done.
# Updating files: 100% (830/830), done.

# %%
# %cd /content/sampling_based_general
# !git pull
# Out:
# /content/sampling_based_general
# Already up to date.

# %%
# !ls /content
# !/content/py310_env/bin/pip install -r requirements.txt
# Out:
# py310_env  sample_data	sampling_based_general
# Collecting absl-py==2.2.2
#   Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 KB 2.6 MB/s eta 0:00:00
# Collecting asttokens==3.0.0
#   Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Collecting cffi==1.17.1
#   Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 KB 7.6 MB/s eta 0:00:00
# Collecting clarabel==0.11.0
#   Downloading clarabel-0.11.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.3 MB/s eta 0:00:00
# Collecting comm==0.2.2
#   Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Collecting contourpy==1.3.1
#   Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 KB 14.4 MB/s eta 0:00:00
# Collecting cycler==0.12.1
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting debugpy==1.8.14
#   Downloading debugpy-1.8.14-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 19.6 MB/s eta 0:00:00
# Collecting decorator==5.2.1
#   Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Collecting etils==1.12.2
#   Downloading etils-1.12.2-py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.6/167.6 KB 27.4 MB/s eta 0:00:00
# Collecting executing==2.2.0
#   Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Collecting filelock==3.18.0
#   Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting fonttools==4.57.0
#   Downloading fonttools-4.57.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 31.5 MB/s eta 0:00:00
# Collecting fsspec==2025.3.2
#   Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 KB 23.4 MB/s eta 0:00:00
# Collecting glfw==2.8.0
#   Downloading glfw-2.8.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 KB 37.6 MB/s eta 0:00:00
# Collecting importlib_resources==6.5.2
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting ipykernel==6.29.5
#   Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 KB 15.0 MB/s eta 0:00:00
# Collecting ipython==8.38.0
#   Downloading ipython-8.38.0-py3-none-any.whl (831 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.8/831.8 KB 36.8 MB/s eta 0:00:00
# Collecting ipython_pygments_lexers==1.1.1
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Collecting jax==0.5.3
#   Downloading jax-0.5.3-py3-none-any.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 41.2 MB/s eta 0:00:00
# Collecting jax-cuda12-pjrt==0.5.3
#   Downloading jax_cuda12_pjrt-0.5.3-py3-none-manylinux2014_x86_64.whl (104.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.7/104.7 MB 8.8 MB/s eta 0:00:00
# Collecting jax-cuda12-plugin==0.5.3
#   Downloading jax_cuda12_plugin-0.5.3-cp310-cp310-manylinux2014_x86_64.whl (16.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 76.5 MB/s eta 0:00:00
# Collecting jaxlib==0.5.3
#   Downloading jaxlib-0.5.3-cp310-cp310-manylinux2014_x86_64.whl (105.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 MB 8.8 MB/s eta 0:00:00
# Collecting jedi==0.19.2
#   Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 102.4 MB/s eta 0:00:00
# Collecting Jinja2==3.1.6
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 KB 26.8 MB/s eta 0:00:00
# Collecting joblib==1.5.1
#   Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 KB 48.7 MB/s eta 0:00:00
# Collecting jupyter_client==8.6.3
#   Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 KB 21.3 MB/s eta 0:00:00
# Collecting jupyter_core==5.7.2
#   Downloading jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Collecting kiwisolver==1.4.8
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 108.3 MB/s eta 0:00:00
# Collecting MarkupSafe==3.0.2
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Collecting matplotlib==3.10.1
#   Downloading matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 104.4 MB/s eta 0:00:00
# Collecting matplotlib-inline==0.1.7
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Collecting ml_dtypes==0.5.1
#   Downloading ml_dtypes-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 143.1 MB/s eta 0:00:00
# Collecting mpmath==1.3.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 71.3 MB/s eta 0:00:00
# Collecting mujoco==3.3.1
#   Downloading mujoco-3.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 109.8 MB/s eta 0:00:00
# Collecting mujoco-mjx==3.3.1
#   Downloading mujoco_mjx-3.3.1-py3-none-any.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 37.4 MB/s eta 0:00:00
# Collecting nest-asyncio==1.6.0
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Collecting networkx==3.4.2
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 110.3 MB/s eta 0:00:00
# Collecting numpy==2.2.4
#   Downloading numpy-2.2.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 69.4 MB/s eta 0:00:00
# Collecting opt_einsum==3.4.0
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 KB 9.0 MB/s eta 0:00:00
# Collecting osqp==1.0.4
#   Downloading osqp-1.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (344 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.6/344.6 KB 47.0 MB/s eta 0:00:00
# Collecting packaging==24.2
#   Downloading packaging-24.2-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 KB 10.4 MB/s eta 0:00:00
# Collecting parso==0.8.4
#   Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.7/103.7 KB 20.2 MB/s eta 0:00:00
# Collecting pexpect==4.9.0
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 KB 11.7 MB/s eta 0:00:00
# Collecting pillow==11.2.1
#   Downloading pillow-11.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 130.9 MB/s eta 0:00:00
# Collecting platformdirs==4.3.8
#   Downloading platformdirs-4.3.8-py3-none-any.whl (18 kB)
# Collecting prompt_toolkit==3.0.51
#   Downloading prompt_toolkit-3.0.51-py3-none-any.whl (387 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.8/387.8 KB 53.1 MB/s eta 0:00:00
# Collecting psutil==7.0.0
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 KB 40.3 MB/s eta 0:00:00
# Collecting ptyprocess==0.7.0
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting pure_eval==0.2.3
#   Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Collecting pycparser==2.22
#   Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 KB 25.1 MB/s eta 0:00:00
# Collecting Pygments==2.19.1
#   Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 86.4 MB/s eta 0:00:00
# Collecting PyOpenGL==3.1.9
#   Downloading PyOpenGL-3.1.9-py3-none-any.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 138.7 MB/s eta 0:00:00
# Collecting pyparsing==3.2.3
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 KB 23.2 MB/s eta 0:00:00
# Collecting python-dateutil==2.9.0.post0
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 KB 44.3 MB/s eta 0:00:00
# Collecting pyzmq==26.4.0
#   Downloading pyzmq-26.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (862 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.5/862.5 KB 59.0 MB/s eta 0:00:00
# Collecting qpsolvers==4.7.0
#   Downloading qpsolvers-4.7.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 KB 20.4 MB/s eta 0:00:00
# Collecting scipy==1.15.2
#   Downloading scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 21.7 MB/s eta 0:00:00
# Collecting setuptools==80.8.0
#   Downloading setuptools-80.8.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 93.8 MB/s eta 0:00:00
# Collecting six==1.17.0
#   Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Collecting stack-data==0.6.3
#   Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Collecting sympy==1.13.1
#   Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 133.9 MB/s eta 0:00:00
# Collecting traitlets==5.14.3
#   Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 KB 16.5 MB/s eta 0:00:00
# Collecting trimesh==4.6.6
#   Downloading trimesh-4.6.6-py3-none-any.whl (709 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 KB 77.0 MB/s eta 0:00:00
# Collecting triton==3.1.0
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 5.5 MB/s eta 0:00:00
# Collecting typing_extensions==4.13.2
#   Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 KB 4.3 MB/s eta 0:00:00
# Collecting wcwidth==0.2.13
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Collecting zipp==3.21.0
#   Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Collecting qpsolvers[daqp]
#   Downloading qpsolvers-4.9.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 KB 15.4 MB/s eta 0:00:00
# Collecting tornado>=6.1
#   Downloading tornado-6.5.4-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (445 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.3/445.3 KB 54.4 MB/s eta 0:00:00
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Collecting etils[epath]
#   Downloading etils-1.13.0-py3-none-any.whl (170 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.6/170.6 KB 31.0 MB/s eta 0:00:00
# Collecting qpsolvers[daqp]
#   Downloading qpsolvers-4.8.2-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 KB 17.7 MB/s eta 0:00:00
#   Downloading qpsolvers-4.8.1-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 KB 18.7 MB/s eta 0:00:00
#   Downloading qpsolvers-4.8.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 KB 19.8 MB/s eta 0:00:00
#   Downloading qpsolvers-4.7.1-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 KB 19.4 MB/s eta 0:00:00
# Collecting daqp>=0.5.1
#   Downloading daqp-0.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (595 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 595.9/595.9 KB 63.5 MB/s eta 0:00:00
# Installing collected packages: wcwidth, PyOpenGL, pure_eval, ptyprocess, mpmath, jax-cuda12-pjrt, glfw, daqp, zipp, typing_extensions, traitlets, tornado, sympy, six, setuptools, pyzmq, pyparsing, Pygments, pycparser, psutil, prompt_toolkit, platformdirs, pillow, pexpect, parso, packaging, opt_einsum, numpy, networkx, nest-asyncio, MarkupSafe, kiwisolver, joblib, jax-cuda12-plugin, importlib_resources, fsspec, fonttools, filelock, executing, etils, decorator, debugpy, cycler, asttokens, absl-py, triton, trimesh, stack-data, scipy, python-dateutil, ml_dtypes, matplotlib-inline, jupyter_core, Jinja2, jedi, ipython_pygments_lexers, exceptiongroup, contourpy, comm, cffi, qpsolvers, osqp, matplotlib, jupyter_client, jaxlib, ipython, clarabel, mujoco, jax, ipykernel, mujoco-mjx
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.1.2
#     Uninstalling setuptools-68.1.2:
#       Successfully uninstalled setuptools-68.1.2
# Successfully installed Jinja2-3.1.6 MarkupSafe-3.0.2 PyOpenGL-3.1.9 Pygments-2.19.1 absl-py-2.2.2 asttokens-3.0.0 cffi-1.17.1 clarabel-0.11.0 comm-0.2.2 contourpy-1.3.1 cycler-0.12.1 daqp-0.7.2 debugpy-1.8.14 decorator-5.2.1 etils-1.12.2 exceptiongroup-1.3.1 executing-2.2.0 filelock-3.18.0 fonttools-4.57.0 fsspec-2025.3.2 glfw-2.8.0 importlib_resources-6.5.2 ipykernel-6.29.5 ipython-8.38.0 ipython_pygments_lexers-1.1.1 jax-0.5.3 jax-cuda12-pjrt-0.5.3 jax-cuda12-plugin-0.5.3 jaxlib-0.5.3 jedi-0.19.2 joblib-1.5.1 jupyter_client-8.6.3 jupyter_core-5.7.2 kiwisolver-1.4.8 matplotlib-3.10.1 matplotlib-inline-0.1.7 ml_dtypes-0.5.1 mpmath-1.3.0 mujoco-3.3.1 mujoco-mjx-3.3.1 nest-asyncio-1.6.0 networkx-3.4.2 numpy-2.2.4 opt_einsum-3.4.0 osqp-1.0.4 packaging-24.2 parso-0.8.4 pexpect-4.9.0 pillow-11.2.1 platformdirs-4.3.8 prompt_toolkit-3.0.51 psutil-7.0.0 ptyprocess-0.7.0 pure_eval-0.2.3 pycparser-2.22 pyparsing-3.2.3 python-dateutil-2.9.0.post0 pyzmq-26.4.0 qpsolvers-4.7.0 scipy-1.15.2 setuptools-80.8.0 six-1.17.0 stack-data-0.6.3 sympy-1.13.1 tornado-6.5.4 traitlets-5.14.3 trimesh-4.6.6 triton-3.1.0 typing_extensions-4.13.2 wcwidth-0.2.13 zipp-3.21.0

# %%
# %cd /content/sampling_based_general/real_demo

# !git clone https://github.com/AKS-Lab-Univertsity-of-Tartu/math_utils_aks_lab.git math_utils
# Out:
# /content/sampling_based_general/real_demo
# Cloning into 'math_utils'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 123 (delta 62), reused 106 (delta 47), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 12.73 MiB | 29.97 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
# %cd /content/sampling_based_general
# Out:
# /content/sampling_based_general

# %%
# !apt-get update
# !apt-get install -y libgl1-mesa-dev libegl1-mesa-dev
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libegl-dev libgl-dev libgles-dev libgles1 libglvnd-core-dev libglvnd-dev
#   libglx-dev libopengl-dev
# The following NEW packages will be installed:
#   libegl-dev libegl1-mesa-dev libgl-dev libgl1-mesa-dev libgles-dev libgles1
#   libglvnd-core-dev libglvnd-dev libglx-dev libopengl-dev
# 0 upgraded, 10 newly installed, 0 to remove and 98 not upgraded.
# Need to get 232 kB of archives.
# After this operation, 2,678 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl-dev amd64 1.4.0-1 [18.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-core-dev amd64 1.4.0-1 [12.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles1 amd64 1.4.0-1 [11.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles-dev amd64 1.4.0-1 [49.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl-dev amd64 1.4.0-1 [3,400 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd-dev amd64 1.4.0-1 [3,162 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libegl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [11.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dev amd64 23.2.1-1ubuntu3.1~22.04.3 [6,848 B]
# Fetched 232 kB in 1s (381 kB/s)
# Selecting previously unselected package libglx-dev:amd64.
# (Reading database ... 121867 files and directories currently installed.)
# Preparing to unpack .../0-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../1-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../2-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../3-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../4-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../5-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../6-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../7-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl1-mesa-dev:amd64.
# Preparing to unpack .../8-libegl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../9-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link

# %%
# !/content/py310_env/bin/pip install imageio[ffmpeg]
# Out:
# Collecting imageio[ffmpeg]
#   Downloading imageio-2.37.2-py3-none-any.whl (317 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.6/317.6 KB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /content/py310_env/lib/python3.10/site-packages (from imageio[ffmpeg]) (2.2.4)
# Requirement already satisfied: pillow>=8.3.2 in /content/py310_env/lib/python3.10/site-packages (from imageio[ffmpeg]) (11.2.1)
# Collecting imageio-ffmpeg
#   Downloading imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl (29.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /content/py310_env/lib/python3.10/site-packages (from imageio[ffmpeg]) (7.0.0)
# Installing collected packages: imageio-ffmpeg, imageio
# Successfully installed imageio-2.37.2 imageio-ffmpeg-0.6.0

# %%
# !python3 -u real_demo/pendulum_demo_pyt_colab.py
# !/content/py310_env/bin/python3.10 real_demo/pendulum_demo_pyt_colab.py --num_batch 500 --maxiter_cem 1 --steps 100
# !/content/py310_env/bin/python3.10 \
    real_demo/walker_demo_pyt_colab.py \
    --num_batch 50 \
    --maxiter_cem 40 \
    --steps 100 \
    --timestep 0.02 \
    --maxiter_projection 1 \
    --num_steps 50
# Out:
# Sensors: 0 1 2
#
# Torque-controlled joints:
#   0: 'rootz' -> controlled: False
#   1: 'rootx' -> controlled: False
#   2: 'rooty' -> controlled: False
#   3: 'right_hip' -> controlled: True
#   4: 'right_knee' -> controlled: True
#   5: 'right_ankle' -> controlled: True
#   6: 'left_hip' -> controlled: True
#   7: 'left_knee' -> controlled: True
#   8: 'left_ankle' -> controlled: True
#
#  Default backend: gpu
#  Timestep: 0.02
#  CEM Iter: 40
#  Projection Iter: 1
#  Number of batches: 50
#  Number of steps per trajectory: 50
#  Time per trajectory: 1.0
#  Number of variables: 66
#  Number of Total constraints: 1800
#
# Step 0
#
# Torso Position: [0.  0.  1.3]
#
# | Total time: 24.9s
# | Step time: 24890.6ms
# | Total Cost (Across Horizon): 654.90
# | Cost Height (Across Horizon): 5.17
# | Cost Orientation (Across Horizon): 0.59
# | Velocity (Across Horizon): 645.85
# | Control (Across Horizon): 3.29
#
# Step 1
#
# Torso Position: [-0.      0.      1.2961]
#
# | Total time: 26.5s
# | Step time: 1530.2ms
# | Total Cost (Across Horizon): 547.95
# | Cost Height (Across Horizon): 11.76
# | Cost Orientation (Across Horizon): 2.13
# | Velocity (Across Horizon): 530.37
# | Control (Across Horizon): 3.69
#
# Step 2
#
# Torso Position: [-0.0001  0.      1.2941]
#
# | Total time: 27.7s
# | Step time: 1185.1ms
# | Total Cost (Across Horizon): 398.71
# | Cost Height (Across Horizon): 14.31
# | Cost Orientation (Across Horizon): 0.93
# | Velocity (Across Horizon): 379.84
# | Control (Across Horizon): 3.63
#
# Step 3
#
# Torso Position: [-0.003   0.      1.2948]
#
# | Total time: 28.9s
# | Step time: 1220.3ms
# | Total Cost (Across Horizon): 399.12
# | Cost Height (Across Horizon): 9.23
# | Cost Orientation (Across Horizon): 1.28
# | Velocity (Across Horizon): 385.20
# | Control (Across Horizon): 3.41
#
# Step 4
#
# Torso Position: [-0.0085  0.      1.2969]
#
# | Total time: 30.1s
# | Step time: 1210.2ms
# | Total Cost (Across Horizon): 402.98
# | Cost Height (Across Horizon): 12.84
# | Cost Orientation (Across Horizon): 1.80
# | Velocity (Across Horizon): 385.04
# | Control (Across Horizon): 3.30
#
# Step 5
#
# Torso Position: [-0.0152  0.      1.2957]
#
# | Total time: 31.3s
# | Step time: 1235.2ms
# | Total Cost (Across Horizon): 356.63
# | Cost Height (Across Horizon): 28.27
# | Cost Orientation (Across Horizon): 0.61
# | Velocity (Across Horizon): 324.29
# | Control (Across Horizon): 3.46
#
# Step 6
#
# Torso Position: [-0.0207  0.      1.2979]
#
# | Total time: 32.8s
# | Step time: 1479.9ms
# | Total Cost (Across Horizon): 343.84
# | Cost Height (Across Horizon): 16.43
# | Cost Orientation (Across Horizon): 1.53
# | Velocity (Across Horizon): 322.31
# | Control (Across Horizon): 3.57
#
# Step 7
#
# Torso Position: [-0.0254  0.      1.2989]
#
# | Total time: 34.2s
# | Step time: 1347.1ms
# | Total Cost (Across Horizon): 330.07
# | Cost Height (Across Horizon): 21.18
# | Cost Orientation (Across Horizon): 2.05
# | Velocity (Across Horizon): 303.26
# | Control (Across Horizon): 3.58
#
# Step 8
#
# Torso Position: [-0.0291  0.      1.2982]
#
# | Total time: 35.4s
# | Step time: 1196.6ms
# | Total Cost (Across Horizon): 316.71
# | Cost Height (Across Horizon): 13.89
# | Cost Orientation (Across Horizon): 1.38
# | Velocity (Across Horizon): 297.99
# | Control (Across Horizon): 3.45
#
# Step 9
#
# Torso Position: [-0.0319  0.      1.2972]
#
# | Total time: 36.6s
# | Step time: 1215.1ms
# | Total Cost (Across Horizon): 359.69
# | Cost Height (Across Horizon): 19.78
# | Cost Orientation (Across Horizon): 0.97
# | Velocity (Across Horizon): 335.40
# | Control (Across Horizon): 3.54
#
# Step 10
#
# Torso Position: [-0.0337  0.      1.2942]
#
# | Total time: 37.8s
# | Step time: 1219.9ms
# | Total Cost (Across Horizon): 373.96
# | Cost Height (Across Horizon): 25.47
# | Cost Orientation (Across Horizon): 2.07
# | Velocity (Across Horizon): 342.91
# | Control (Across Horizon): 3.52
#
# Step 11
#
# Torso Position: [-0.0259  0.      1.2934]
#
# | Total time: 39.0s
# | Step time: 1208.1ms
# | Total Cost (Across Horizon): 329.73
# | Cost Height (Across Horizon): 27.47
# | Cost Orientation (Across Horizon): 6.96
# | Velocity (Across Horizon): 291.85
# | Control (Across Horizon): 3.44
#
# Step 12
#
# Torso Position: [-0.0116  0.      1.2928]
#
# | Total time: 40.2s
# | Step time: 1210.3ms
# | Total Cost (Across Horizon): 291.67
# | Cost Height (Across Horizon): 28.29
# | Cost Orientation (Across Horizon): 9.49
# | Velocity (Across Horizon): 250.49
# | Control (Across Horizon): 3.41
#
# Step 13
#
# Torso Position: [0.0022 0.     1.3015]
#
# | Total time: 41.5s
# | Step time: 1213.4ms
# | Total Cost (Across Horizon): 280.89
# | Cost Height (Across Horizon): 33.40
# | Cost Orientation (Across Horizon): 2.11
# | Velocity (Across Horizon): 241.89
# | Control (Across Horizon): 3.50
#
# Step 14
#
# Torso Position: [0.0099 0.     1.3126]
#
# | Total time: 42.7s
# | Step time: 1208.9ms
# | Total Cost (Across Horizon): 254.06
# | Cost Height (Across Horizon): 45.07
# | Cost Orientation (Across Horizon): 3.70
# | Velocity (Across Horizon): 202.03
# | Control (Across Horizon): 3.27
#
# Step 15
#
# Torso Position: [0.0095 0.     1.3329]
#
# | Total time: 43.9s
# | Step time: 1257.9ms
# | Total Cost (Across Horizon): 248.48
# | Cost Height (Across Horizon): 43.84
# | Cost Orientation (Across Horizon): 2.93
# | Velocity (Across Horizon): 198.47
# | Control (Across Horizon): 3.25
#
# Step 16
#
# Torso Position: [0.0069 0.     1.3524]
#
# | Total time: 45.4s
# | Step time: 1508.5ms
# | Total Cost (Across Horizon): 240.79
# | Cost Height (Across Horizon): 43.67
# | Cost Orientation (Across Horizon): 2.83
# | Velocity (Across Horizon): 190.96
# | Control (Across Horizon): 3.32
#
# Step 17
#
# Torso Position: [0.0052 0.     1.3658]
#
# | Total time: 46.7s
# | Step time: 1292.2ms
# | Total Cost (Across Horizon): 240.64
# | Cost Height (Across Horizon): 39.78
# | Cost Orientation (Across Horizon): 5.57
# | Velocity (Across Horizon): 191.99
# | Control (Across Horizon): 3.29
#
# Step 18
#
# Torso Position: [0.0061 0.     1.3737]
#
# | Total time: 47.9s
# | Step time: 1196.8ms
# | Total Cost (Across Horizon): 220.49
# | Cost Height (Across Horizon): 32.34
# | Cost Orientation (Across Horizon): 5.61
# | Velocity (Across Horizon): 179.00
# | Control (Across Horizon): 3.54
#
# Step 19
#
# Torso Position: [0.0097 0.     1.3759]
#
# | Total time: 49.1s
# | Step time: 1217.6ms
# | Total Cost (Across Horizon): 211.82
# | Cost Height (Across Horizon): 39.89
# | Cost Orientation (Across Horizon): 5.29
# | Velocity (Across Horizon): 162.98
# | Control (Across Horizon): 3.66
#
# Step 20
#
# Torso Position: [0.0149 0.     1.3719]
#
# | Total time: 50.4s
# | Step time: 1215.1ms
# | Total Cost (Across Horizon): 194.95
# | Cost Height (Across Horizon): 32.00
# | Cost Orientation (Across Horizon): 10.95
# | Velocity (Across Horizon): 148.26
# | Control (Across Horizon): 3.74
#
# Step 21
#
# Torso Position: [0.0217 0.     1.3622]
#
# | Total time: 51.6s
# | Step time: 1214.7ms
# | Total Cost (Across Horizon): 190.60
# | Cost Height (Across Horizon): 44.80
# | Cost Orientation (Across Horizon): 13.41
# | Velocity (Across Horizon): 128.64
# | Control (Across Horizon): 3.76
#
# Step 22
#
# Torso Position: [0.0301 0.     1.3468]
#
# | Total time: 52.8s
# | Step time: 1203.0ms
# | Total Cost (Across Horizon): 194.59
# | Cost Height (Across Horizon): 52.01
# | Cost Orientation (Across Horizon): 12.62
# | Velocity (Across Horizon): 126.23
# | Control (Across Horizon): 3.72
#
# Step 23
#
# Torso Position: [0.0401 0.     1.3262]
#
# | Total time: 54.0s
# | Step time: 1207.8ms
# | Total Cost (Across Horizon): 204.10
# | Cost Height (Across Horizon): 49.06
# | Cost Orientation (Across Horizon): 11.74
# | Velocity (Across Horizon): 139.67
# | Control (Across Horizon): 3.64
#
# Step 24
#
# Torso Position: [0.0473 0.     1.3034]
#
# | Total time: 55.2s
# | Step time: 1205.0ms
# | Total Cost (Across Horizon): 214.46
# | Cost Height (Across Horizon): 50.01
# | Cost Orientation (Across Horizon): 18.31
# | Velocity (Across Horizon): 142.64
# | Control (Across Horizon): 3.51
#
# Step 25
#
# Torso Position: [0.0569 0.     1.3003]
#
# | Total time: 56.5s
# | Step time: 1245.1ms
# | Total Cost (Across Horizon): 191.67
# | Cost Height (Across Horizon): 33.78
# | Cost Orientation (Across Horizon): 8.51
# | Velocity (Across Horizon): 145.98
# | Control (Across Horizon): 3.40
#
# Step 26
#
# Torso Position: [0.0695 0.     1.3062]
#
# | Total time: 58.1s
# | Step time: 1615.4ms
# | Total Cost (Across Horizon): 213.63
# | Cost Height (Across Horizon): 42.65
# | Cost Orientation (Across Horizon): 16.67
# | Velocity (Across Horizon): 150.86
# | Control (Across Horizon): 3.46
#
# Step 27
#
# Torso Position: [0.084  0.     1.3071]
#
# | Total time: 59.4s
# | Step time: 1295.1ms
# | Total Cost (Across Horizon): 197.47
# | Cost Height (Across Horizon): 62.97
# | Cost Orientation (Across Horizon): 5.72
# | Velocity (Across Horizon): 125.24
# | Control (Across Horizon): 3.53
#
# Step 28
#
# Torso Position: [0.1006 0.     1.3031]
#
# | Total time: 60.6s
# | Step time: 1223.5ms
# | Total Cost (Across Horizon): 178.64
# | Cost Height (Across Horizon): 71.67
# | Cost Orientation (Across Horizon): 17.01
# | Velocity (Across Horizon): 86.44
# | Control (Across Horizon): 3.51
#
# Step 29
#
# Torso Position: [0.1191 0.     1.2934]
#
# | Total time: 61.8s
# | Step time: 1234.0ms
# | Total Cost (Across Horizon): 172.35
# | Cost Height (Across Horizon): 65.93
# | Cost Orientation (Across Horizon): 16.56
# | Velocity (Across Horizon): 86.29
# | Control (Across Horizon): 3.56
#
# Step 30
#
# Torso Position: [0.1405 0.     1.2845]
#
# | Total time: 63.0s
# | Step time: 1207.6ms
# | Total Cost (Across Horizon): 250.01
# | Cost Height (Across Horizon): 78.51
# | Cost Orientation (Across Horizon): 16.28
# | Velocity (Across Horizon): 151.49
# | Control (Across Horizon): 3.73
#
# Step 31
#
# Torso Position: [0.1643 0.     1.2774]
#
# | Total time: 64.2s
# | Step time: 1198.0ms
# | Total Cost (Across Horizon): 209.23
# | Cost Height (Across Horizon): 92.63
# | Cost Orientation (Across Horizon): 53.33
# | Velocity (Across Horizon): 59.54
# | Control (Across Horizon): 3.73
#
# Step 32
#
# Torso Position: [0.19   0.     1.2771]
#
# | Total time: 65.5s
# | Step time: 1209.4ms
# | Total Cost (Across Horizon): 245.79
# | Cost Height (Across Horizon): 117.26
# | Cost Orientation (Across Horizon): 20.49
# | Velocity (Across Horizon): 104.21
# | Control (Across Horizon): 3.83
#
# Step 33
#
# Torso Position: [0.2177 0.     1.279 ]
#
# | Total time: 66.7s
# | Step time: 1196.7ms
# | Total Cost (Across Horizon): 344.48
# | Cost Height (Across Horizon): 98.65
# | Cost Orientation (Across Horizon): 18.86
# | Velocity (Across Horizon): 223.24
# | Control (Across Horizon): 3.73
#
# Step 34
#
# Torso Position: [0.2474 0.     1.2798]
#
# | Total time: 67.9s
# | Step time: 1212.1ms
# | Total Cost (Across Horizon): 229.92
# | Cost Height (Across Horizon): 134.18
# | Cost Orientation (Across Horizon): 35.31
# | Velocity (Across Horizon): 56.39
# | Control (Across Horizon): 4.04
#
# Step 35
#
# Torso Position: [0.2765 0.     1.2751]
#
# | Total time: 69.1s
# | Step time: 1270.0ms
# | Total Cost (Across Horizon): 251.37
# | Cost Height (Across Horizon): 120.14
# | Cost Orientation (Across Horizon): 20.93
# | Velocity (Across Horizon): 106.18
# | Control (Across Horizon): 4.12
#
# Step 36
#
# Torso Position: [0.3057 0.     1.2639]
#
# | Total time: 70.7s
# | Step time: 1539.7ms
# | Total Cost (Across Horizon): 267.08
# | Cost Height (Across Horizon): 99.54
# | Cost Orientation (Across Horizon): 38.92
# | Velocity (Across Horizon): 124.59
# | Control (Across Horizon): 4.04
#
# Step 37
#
# Torso Position: [0.3366 0.     1.2474]
#
# | Total time: 71.9s
# | Step time: 1249.1ms
# | Total Cost (Across Horizon): 250.54
# | Cost Height (Across Horizon): 81.75
# | Cost Orientation (Across Horizon): 29.86
# | Velocity (Across Horizon): 134.88
# | Control (Across Horizon): 4.05
#
# Step 38
#
# Torso Position: [0.3709 0.     1.2326]
#
# | Total time: 73.2s
# | Step time: 1214.6ms
# | Total Cost (Across Horizon): 293.87
# | Cost Height (Across Horizon): 81.47
# | Cost Orientation (Across Horizon): 29.73
# | Velocity (Across Horizon): 178.72
# | Control (Across Horizon): 3.96
#
# Step 39
#
# Torso Position: [0.4072 0.     1.2173]
#
# | Total time: 74.4s
# | Step time: 1223.9ms
# | Total Cost (Across Horizon): 286.05
# | Cost Height (Across Horizon): 116.08
# | Cost Orientation (Across Horizon): 41.78
# | Velocity (Across Horizon): 124.28
# | Control (Across Horizon): 3.90
#
# Step 40
#
# Torso Position: [0.4462 0.     1.2097]
#
# | Total time: 75.6s
# | Step time: 1206.3ms
# | Total Cost (Across Horizon): 274.91
# | Cost Height (Across Horizon): 80.07
# | Cost Orientation (Across Horizon): 37.33
# | Velocity (Across Horizon): 153.36
# | Control (Across Horizon): 4.15
#
# Step 41
#
# Torso Position: [0.4867 0.     1.2021]
#
# | Total time: 76.8s
# | Step time: 1196.4ms
# | Total Cost (Across Horizon): 332.58
# | Cost Height (Across Horizon): 123.09
# | Cost Orientation (Across Horizon): 43.16
# | Velocity (Across Horizon): 162.17
# | Control (Across Horizon): 4.16
#
# Step 42
#
# Torso Position: [0.5271 0.     1.1903]
#
# | Total time: 78.0s
# | Step time: 1215.8ms
# | Total Cost (Across Horizon): 353.89
# | Cost Height (Across Horizon): 162.24
# | Cost Orientation (Across Horizon): 69.55
# | Velocity (Across Horizon): 118.10
# | Control (Across Horizon): 4.01
#
# Step 43
#
# Torso Position: [0.568  0.     1.1739]
#
# | Total time: 79.2s
# | Step time: 1205.6ms
# | Total Cost (Across Horizon): 359.68
# | Cost Height (Across Horizon): 106.53
# | Cost Orientation (Across Horizon): 31.86
# | Velocity (Across Horizon): 217.39
# | Control (Across Horizon): 3.90
#
# Step 44
#
# Torso Position: [0.6088 0.     1.1535]
#
# | Total time: 80.5s
# | Step time: 1233.9ms
# | Total Cost (Across Horizon): 412.17
# | Cost Height (Across Horizon): 121.20
# | Cost Orientation (Across Horizon): 54.38
# | Velocity (Across Horizon): 232.58
# | Control (Across Horizon): 4.01
#
# Step 45
#
# Torso Position: [0.6495 0.     1.1287]
#
# | Total time: 81.7s
# | Step time: 1260.6ms
# | Total Cost (Across Horizon): 508.31
# | Cost Height (Across Horizon): 185.43
# | Cost Orientation (Across Horizon): 29.46
# | Velocity (Across Horizon): 289.63
# | Control (Across Horizon): 3.79
#
# Step 46
#
# Torso Position: [0.6903 0.     1.0998]
#
# | Total time: 83.2s
# | Step time: 1514.7ms
# | Total Cost (Across Horizon): 544.15
# | Cost Height (Across Horizon): 200.47
# | Cost Orientation (Across Horizon): 41.39
# | Velocity (Across Horizon): 298.49
# | Control (Across Horizon): 3.79
#
# Step 47
#
# Torso Position: [0.731  0.     1.0668]
#
# | Total time: 84.5s
# | Step time: 1244.5ms
# | Total Cost (Across Horizon): 508.15
# | Cost Height (Across Horizon): 202.39
# | Cost Orientation (Across Horizon): 53.97
# | Velocity (Across Horizon): 247.76
# | Control (Across Horizon): 4.03
#
# Step 48
#
# Torso Position: [0.7752 0.     1.0331]
#
# | Total time: 85.7s
# | Step time: 1209.5ms
# | Total Cost (Across Horizon): 612.97
# | Cost Height (Across Horizon): 225.17
# | Cost Orientation (Across Horizon): 95.75
# | Velocity (Across Horizon): 288.06
# | Control (Across Horizon): 4.00
#
# Step 49
#
# Torso Position: [0.8106 0.     0.9989]
#
# | Total time: 86.9s
# | Step time: 1206.6ms
# | Total Cost (Across Horizon): 676.21
# | Cost Height (Across Horizon): 228.35
# | Cost Orientation (Across Horizon): 111.13
# | Velocity (Across Horizon): 332.70
# | Control (Across Horizon): 4.04
#
# Step 50
#
# Torso Position: [0.8515 0.     0.9723]
#
# | Total time: 88.1s
# | Step time: 1191.0ms
# | Total Cost (Across Horizon): 606.75
# | Cost Height (Across Horizon): 245.31
# | Cost Orientation (Across Horizon): 149.75
# | Velocity (Across Horizon): 207.44
# | Control (Across Horizon): 4.24
#
# Step 51
#
# Torso Position: [0.8949 0.     0.946 ]
#
# | Total time: 89.3s
# | Step time: 1201.0ms
# | Total Cost (Across Horizon): 679.76
# | Cost Height (Across Horizon): 182.66
# | Cost Orientation (Across Horizon): 119.46
# | Velocity (Across Horizon): 373.59
# | Control (Across Horizon): 4.07
#
# Step 52
#
# Torso Position: [0.9399 0.     0.9146]
#
# | Total time: 90.5s
# | Step time: 1208.2ms
# | Total Cost (Across Horizon): 695.25
# | Cost Height (Across Horizon): 228.03
# | Cost Orientation (Across Horizon): 95.65
# | Velocity (Across Horizon): 367.54
# | Control (Across Horizon): 4.03
#
# Step 53
#
# Torso Position: [0.9816 0.     0.8846]
#
# | Total time: 91.7s
# | Step time: 1201.0ms
# | Total Cost (Across Horizon): 666.22
# | Cost Height (Across Horizon): 229.53
# | Cost Orientation (Across Horizon): 84.07
# | Velocity (Across Horizon): 348.60
# | Control (Across Horizon): 4.02
#
# Step 54
#
# Torso Position: [1.0185 0.     0.8725]
#
# | Total time: 92.9s
# | Step time: 1215.2ms
# | Total Cost (Across Horizon): 704.69
# | Cost Height (Across Horizon): 233.21
# | Cost Orientation (Across Horizon): 106.52
# | Velocity (Across Horizon): 360.96
# | Control (Across Horizon): 3.99
#
# Step 55
#
# Torso Position: [1.0401 0.     0.8657]
#
# | Total time: 94.2s
# | Step time: 1220.3ms
# | Total Cost (Across Horizon): 728.38
# | Cost Height (Across Horizon): 244.70
# | Cost Orientation (Across Horizon): 117.29
# | Velocity (Across Horizon): 362.20
# | Control (Across Horizon): 4.19
#
# Step 56
#
# Torso Position: [1.0573 0.     0.8647]
#
# | Total time: 95.7s
# | Step time: 1525.1ms
# | Total Cost (Across Horizon): 723.21
# | Cost Height (Across Horizon): 245.41
# | Cost Orientation (Across Horizon): 170.47
# | Velocity (Across Horizon): 303.01
# | Control (Across Horizon): 4.32
#
# Step 57
#
# Torso Position: [1.0714 0.     0.8659]
#
# | Total time: 96.9s
# | Step time: 1243.1ms
# | Total Cost (Across Horizon): 717.18
# | Cost Height (Across Horizon): 248.32
# | Cost Orientation (Across Horizon): 181.33
# | Velocity (Across Horizon): 283.19
# | Control (Across Horizon): 4.34
#
# Step 58
#
# Torso Position: [1.0861 0.     0.8673]
#
# | Total time: 98.1s
# | Step time: 1207.8ms
# | Total Cost (Across Horizon): 739.89
# | Cost Height (Across Horizon): 233.55
# | Cost Orientation (Across Horizon): 114.68
# | Velocity (Across Horizon): 387.36
# | Control (Across Horizon): 4.31
#
# Step 59
#
# Torso Position: [1.1026 0.     0.8678]
#
# | Total time: 99.4s
# | Step time: 1209.3ms
# | Total Cost (Across Horizon): 739.61
# | Cost Height (Across Horizon): 245.28
# | Cost Orientation (Across Horizon): 131.13
# | Velocity (Across Horizon): 358.87
# | Control (Across Horizon): 4.32
#
# Step 60
#
# Torso Position: [1.1199 0.     0.8676]
#
# | Total time: 100.6s
# | Step time: 1208.7ms
# | Total Cost (Across Horizon): 803.24
# | Cost Height (Across Horizon): 269.87
# | Cost Orientation (Across Horizon): 225.12
# | Velocity (Across Horizon): 303.74
# | Control (Across Horizon): 4.51
#
# Step 61
#
# Torso Position: [1.1358 0.     0.8645]
#
# | Total time: 101.8s
# | Step time: 1199.2ms
# | Total Cost (Across Horizon): 749.21
# | Cost Height (Across Horizon): 248.69
# | Cost Orientation (Across Horizon): 74.18
# | Velocity (Across Horizon): 421.69
# | Control (Across Horizon): 4.65
#
# Step 62
#
# Torso Position: [1.1513 0.     0.8598]
#
# | Total time: 103.0s
# | Step time: 1207.7ms
# | Total Cost (Across Horizon): 766.78
# | Cost Height (Across Horizon): 239.14
# | Cost Orientation (Across Horizon): 113.05
# | Velocity (Across Horizon): 410.13
# | Control (Across Horizon): 4.46
#
# Step 63
#
# Torso Position: [1.1674 0.     0.8547]
#
# | Total time: 104.2s
# | Step time: 1224.6ms
# | Total Cost (Across Horizon): 743.70
# | Cost Height (Across Horizon): 255.21
# | Cost Orientation (Across Horizon): 114.79
# | Velocity (Across Horizon): 369.04
# | Control (Across Horizon): 4.67
#
# Step 64
#
# Torso Position: [1.1844 0.     0.8488]
#
# | Total time: 105.4s
# | Step time: 1218.4ms
# | Total Cost (Across Horizon): 842.31
# | Cost Height (Across Horizon): 267.83
# | Cost Orientation (Across Horizon): 126.24
# | Velocity (Across Horizon): 443.66
# | Control (Across Horizon): 4.59
#
# Step 65
#
# Torso Position: [1.2028 0.     0.8419]
#
# | Total time: 106.7s
# | Step time: 1240.2ms
# | Total Cost (Across Horizon): 896.21
# | Cost Height (Across Horizon): 295.61
# | Cost Orientation (Across Horizon): 213.65
# | Velocity (Across Horizon): 382.47
# | Control (Across Horizon): 4.49
#
# Step 66
#
# Torso Position: [1.2224 0.     0.8332]
#
# | Total time: 109.8s
# | Step time: 3109.7ms
# | Total Cost (Across Horizon): 930.04
# | Cost Height (Across Horizon): 287.45
# | Cost Orientation (Across Horizon): 173.26
# | Velocity (Across Horizon): 464.57
# | Control (Across Horizon): 4.75
#
# Step 67
#
# Torso Position: [1.2436 0.     0.822 ]
#
# | Total time: 111.1s
# | Step time: 1338.5ms
# | Total Cost (Across Horizon): 769.49
# | Cost Height (Across Horizon): 274.73
# | Cost Orientation (Across Horizon): 212.13
# | Velocity (Across Horizon): 277.79
# | Control (Across Horizon): 4.85
#
# Step 68
#
# Torso Position: [1.2663 0.     0.8078]
#
# | Total time: 112.3s
# | Step time: 1194.4ms
# | Total Cost (Across Horizon): 1040.12
# | Cost Height (Across Horizon): 338.88
# | Cost Orientation (Across Horizon): 325.43
# | Velocity (Across Horizon): 370.79
# | Control (Across Horizon): 5.01
#
# Step 69
#
# Torso Position: [1.2895 0.     0.7906]
#
# | Total time: 113.5s
# | Step time: 1190.7ms
# | Total Cost (Across Horizon): 1055.05
# | Cost Height (Across Horizon): 313.60
# | Cost Orientation (Across Horizon): 248.75
# | Velocity (Across Horizon): 487.88
# | Control (Across Horizon): 4.82
#
# Step 70
#
# Torso Position: [1.3116 0.     0.7794]
#
# | Total time: 114.7s
# | Step time: 1200.6ms
# | Total Cost (Across Horizon): 1098.37
# | Cost Height (Across Horizon): 345.63
# | Cost Orientation (Across Horizon): 362.85
# | Velocity (Across Horizon): 384.87
# | Control (Across Horizon): 5.02
#
# Step 71
#
# Torso Position: [1.3341 0.     0.7688]
#
# | Total time: 115.9s
# | Step time: 1210.6ms
# | Total Cost (Across Horizon): 1125.05
# | Cost Height (Across Horizon): 336.39
# | Cost Orientation (Across Horizon): 343.17
# | Velocity (Across Horizon): 440.44
# | Control (Across Horizon): 5.04
#
# Step 72
#
# Torso Position: [1.3573 0.     0.7583]
#
# | Total time: 117.1s
# | Step time: 1202.8ms
# | Total Cost (Across Horizon): 1136.68
# | Cost Height (Across Horizon): 329.89
# | Cost Orientation (Across Horizon): 255.04
# | Velocity (Across Horizon): 546.80
# | Control (Across Horizon): 4.95
#
# Step 73
#
# Torso Position: [1.3816 0.     0.7465]
#
# | Total time: 118.3s
# | Step time: 1187.4ms
# | Total Cost (Across Horizon): 1070.38
# | Cost Height (Across Horizon): 333.14
# | Cost Orientation (Across Horizon): 323.14
# | Velocity (Across Horizon): 409.14
# | Control (Across Horizon): 4.96
#
# Step 74
#
# Torso Position: [1.4077 0.     0.7307]
#
# | Total time: 119.5s
# | Step time: 1193.6ms
# | Total Cost (Across Horizon): 1236.98
# | Cost Height (Across Horizon): 324.90
# | Cost Orientation (Across Horizon): 174.29
# | Velocity (Across Horizon): 732.82
# | Control (Across Horizon): 4.98
#
# Step 75
#
# Torso Position: [1.4339 0.     0.7115]
#
# | Total time: 121.0s
# | Step time: 1523.5ms
# | Total Cost (Across Horizon): 1186.30
# | Cost Height (Across Horizon): 341.52
# | Cost Orientation (Across Horizon): 298.83
# | Velocity (Across Horizon): 540.88
# | Control (Across Horizon): 5.07
#
# Step 76
#
# Torso Position: [1.4601 0.     0.6884]
#
# | Total time: 122.3s
# | Step time: 1287.0ms
# | Total Cost (Across Horizon): 1141.20
# | Cost Height (Across Horizon): 380.56
# | Cost Orientation (Across Horizon): 389.14
# | Velocity (Across Horizon): 366.62
# | Control (Across Horizon): 4.87
#
# Step 77
#
# Torso Position: [1.4858 0.     0.6618]
#
# | Total time: 123.5s
# | Step time: 1203.3ms
# | Total Cost (Across Horizon): 955.80
# | Cost Height (Across Horizon): 327.30
# | Cost Orientation (Across Horizon): 275.86
# | Velocity (Across Horizon): 347.56
# | Control (Across Horizon): 5.08
#
# Step 78
#
# Torso Position: [1.5118 0.     0.6327]
#
# | Total time: 124.7s
# | Step time: 1194.3ms
# | Total Cost (Across Horizon): 1239.01
# | Cost Height (Across Horizon): 344.79
# | Cost Orientation (Across Horizon): 334.73
# | Velocity (Across Horizon): 554.29
# | Control (Across Horizon): 5.19
#
# Step 79
#
# Torso Position: [1.5378 0.     0.6004]
#
# | Total time: 125.9s
# | Step time: 1194.4ms
# | Total Cost (Across Horizon): 1427.97
# | Cost Height (Across Horizon): 357.98
# | Cost Orientation (Across Horizon): 148.78
# | Velocity (Across Horizon): 915.96
# | Control (Across Horizon): 5.25
#
# Step 80
#
# Torso Position: [1.5634 0.     0.5657]
#
# | Total time: 127.1s
# | Step time: 1185.9ms
# | Total Cost (Across Horizon): 1427.30
# | Cost Height (Across Horizon): 350.85
# | Cost Orientation (Across Horizon): 246.82
# | Velocity (Across Horizon): 824.30
# | Control (Across Horizon): 5.34
#
# Step 81
#
# Torso Position: [1.5895 0.     0.5298]
#
# | Total time: 128.3s
# | Step time: 1189.8ms
# | Total Cost (Across Horizon): 1613.28
# | Cost Height (Across Horizon): 353.22
# | Cost Orientation (Across Horizon): 147.53
# | Velocity (Across Horizon): 1107.15
# | Control (Across Horizon): 5.39
#
# Step 82
#
# Torso Position: [1.6165 0.     0.4953]
#
# | Total time: 129.5s
# | Step time: 1211.5ms
# | Total Cost (Across Horizon): 1690.03
# | Cost Height (Across Horizon): 356.06
# | Cost Orientation (Across Horizon): 127.48
# | Velocity (Across Horizon): 1201.29
# | Control (Across Horizon): 5.21
#
# Step 83
#
# Torso Position: [1.6188 0.     0.4939]
#
# | Total time: 130.7s
# | Step time: 1207.5ms
# | Total Cost (Across Horizon): 1627.75
# | Cost Height (Across Horizon): 356.55
# | Cost Orientation (Across Horizon): 148.17
# | Velocity (Across Horizon): 1117.70
# | Control (Across Horizon): 5.34
#
# Step 84
#
# Torso Position: [1.6166 0.     0.498 ]
#
# | Total time: 131.9s
# | Step time: 1189.6ms
# | Total Cost (Across Horizon): 1368.87
# | Cost Height (Across Horizon): 318.83
# | Cost Orientation (Across Horizon): 180.16
# | Velocity (Across Horizon): 864.82
# | Control (Across Horizon): 5.06
#
# Step 85
#
# Torso Position: [1.6114 0.     0.4998]
#
# | Total time: 133.4s
# | Step time: 1487.9ms
# | Total Cost (Across Horizon): 1274.16
# | Cost Height (Across Horizon): 320.24
# | Cost Orientation (Across Horizon): 215.60
# | Velocity (Across Horizon): 733.03
# | Control (Across Horizon): 5.28
#
# Step 86
#
# Torso Position: [1.6046 0.     0.507 ]
#
# | Total time: 134.8s
# | Step time: 1377.8ms
# | Total Cost (Across Horizon): 1125.81
# | Cost Height (Across Horizon): 326.20
# | Cost Orientation (Across Horizon): 270.90
# | Velocity (Across Horizon): 523.44
# | Control (Across Horizon): 5.28
#
# Step 87
#
# Torso Position: [1.5955 0.     0.5172]
#
# | Total time: 136.0s
# | Step time: 1207.1ms
# | Total Cost (Across Horizon): 1022.11
# | Cost Height (Across Horizon): 277.53
# | Cost Orientation (Across Horizon): 140.17
# | Velocity (Across Horizon): 599.22
# | Control (Across Horizon): 5.19
#
# Step 88
#
# Torso Position: [1.5847 0.     0.5296]
#
# | Total time: 137.2s
# | Step time: 1189.3ms
# | Total Cost (Across Horizon): 1088.13
# | Cost Height (Across Horizon): 298.20
# | Cost Orientation (Across Horizon): 201.08
# | Velocity (Across Horizon): 583.79
# | Control (Across Horizon): 5.06
#
# Step 89
#
# Torso Position: [1.5774 0.     0.5397]
#
# | Total time: 138.4s
# | Step time: 1192.8ms
# | Total Cost (Across Horizon): 1056.62
# | Cost Height (Across Horizon): 323.22
# | Cost Orientation (Across Horizon): 210.10
# | Velocity (Across Horizon): 517.86
# | Control (Across Horizon): 5.44
#
# Step 90
#
# Torso Position: [1.5707 0.     0.548 ]
#
# | Total time: 139.6s
# | Step time: 1197.8ms
# | Total Cost (Across Horizon): 1080.54
# | Cost Height (Across Horizon): 286.59
# | Cost Orientation (Across Horizon): 172.24
# | Velocity (Across Horizon): 616.15
# | Control (Across Horizon): 5.56
#
# Step 91
#
# Torso Position: [1.5736 0.     0.5564]
#
# | Total time: 140.8s
# | Step time: 1210.7ms
# | Total Cost (Across Horizon): 976.91
# | Cost Height (Across Horizon): 284.80
# | Cost Orientation (Across Horizon): 149.58
# | Velocity (Across Horizon): 536.86
# | Control (Across Horizon): 5.67
#
# Step 92
#
# Torso Position: [1.5862 0.     0.5651]
#
# | Total time: 142.0s
# | Step time: 1200.4ms
# | Total Cost (Across Horizon): 953.55
# | Cost Height (Across Horizon): 292.09
# | Cost Orientation (Across Horizon): 215.18
# | Velocity (Across Horizon): 440.56
# | Control (Across Horizon): 5.72
#
# Step 93
#
# Torso Position: [1.5943 0.     0.5726]
#
# | Total time: 143.2s
# | Step time: 1213.4ms
# | Total Cost (Across Horizon): 945.18
# | Cost Height (Across Horizon): 284.18
# | Cost Orientation (Across Horizon): 151.68
# | Velocity (Across Horizon): 503.41
# | Control (Across Horizon): 5.90
#
# Step 94
#
# Torso Position: [1.6017 0.     0.5809]
#
# | Total time: 144.4s
# | Step time: 1203.4ms
# | Total Cost (Across Horizon): 991.57
# | Cost Height (Across Horizon): 276.37
# | Cost Orientation (Across Horizon): 145.79
# | Velocity (Across Horizon): 563.72
# | Control (Across Horizon): 5.69
#
# Step 95
#
# Torso Position: [1.61   0.     0.5889]
#
# | Total time: 145.9s
# | Step time: 1449.3ms
# | Total Cost (Across Horizon): 874.23
# | Cost Height (Across Horizon): 260.67
# | Cost Orientation (Across Horizon): 118.25
# | Velocity (Across Horizon): 489.76
# | Control (Across Horizon): 5.55
#
# Step 96
#
# Torso Position: [1.6188 0.     0.5967]
#
# | Total time: 147.3s
# | Step time: 1395.4ms
# | Total Cost (Across Horizon): 901.91
# | Cost Height (Across Horizon): 317.07
# | Cost Orientation (Across Horizon): 140.53
# | Velocity (Across Horizon): 438.71
# | Control (Across Horizon): 5.60
#
# Step 97
#
# Torso Position: [1.629  0.     0.6037]
#
# | Total time: 148.5s
# | Step time: 1250.4ms
# | Total Cost (Across Horizon): 854.73
# | Cost Height (Across Horizon): 274.07
# | Cost Orientation (Across Horizon): 88.25
# | Velocity (Across Horizon): 486.94
# | Control (Across Horizon): 5.48
#
# Step 98
#
# Torso Position: [1.6381 0.     0.6086]
#
# | Total time: 149.7s
# | Step time: 1195.4ms
# | Total Cost (Across Horizon): 937.55
# | Cost Height (Across Horizon): 249.85
# | Cost Orientation (Across Horizon): 81.26
# | Velocity (Across Horizon): 600.89
# | Control (Across Horizon): 5.55
#
# Step 99
#
# Torso Position: [1.6463 0.     0.6118]
#
# | Total time: 150.9s
# | Step time: 1192.4ms
# | Total Cost (Across Horizon): 825.25
# | Cost Height (Across Horizon): 246.55
# | Cost Orientation (Across Horizon): 72.07
# | Velocity (Across Horizon): 500.85
# | Control (Across Horizon): 5.77
# /usr/lib/python3.10/subprocess.py:1796: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _posixsubprocess.fork_exec(
#
# Video saved: walker_video.mp4

# %%
from IPython.display import Video
Video("walker_video.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
