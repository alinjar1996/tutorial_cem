# %% [markdown]
# <a href="https://colab.research.google.com/github/alinjar1996/tutorial_cem/blob/main/tutorial_biped.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update
# !sudo apt-get install python3.10 python3.10-venv python3.10-distutils

# %%
# !python3.10 -m venv py310_env

# %%
# !py310_env/bin/python -m ensurepip
# !py310_env/bin/pip install pip==22.0.2
# Out:
# Looking in links: /tmp/tmpys6vxujj
# Requirement already satisfied: setuptools in ./py310_env/lib/python3.10/site-packages (68.1.2)
# Requirement already satisfied: pip in ./py310_env/lib/python3.10/site-packages (22.0.2)
# Requirement already satisfied: pip==22.0.2 in ./py310_env/lib/python3.10/site-packages (22.0.2)

# %%
# !py310_env/bin/python --version
# !py310_env/bin/pip --version
# Out:
# Python 3.10.12
# pip 22.0.2 from /content/py310_env/lib/python3.10/site-packages/pip (python 3.10)

# %%
# !git clone https://github.com/alinjar1996/sampling_based_general.git -b issue_1_biped_torque
# Out:
# Cloning into 'sampling_based_general'...
# remote: Enumerating objects: 3905, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 3905 (delta 88), reused 96 (delta 48), pack-reused 3759 (from 2)
# Receiving objects: 100% (3905/3905), 573.78 MiB | 17.44 MiB/s, done.
# Resolving deltas: 100% (1938/1938), done.
# Updating files: 100% (830/830), done.

# %%
# %cd /content/sampling_based_general
# !git pull
# Out:
# /content/sampling_based_general
# Already up to date.

# %%
# !ls /content
# !/content/py310_env/bin/pip install -r requirements.txt

# %%
# %cd /content/sampling_based_general/real_demo

# !git clone https://github.com/AKS-Lab-Univertsity-of-Tartu/math_utils_aks_lab.git math_utils
# Out:
# /content/sampling_based_general/real_demo
# Cloning into 'math_utils'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 123 (delta 62), reused 106 (delta 47), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 12.73 MiB | 14.80 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
# %cd /content/sampling_based_general
# Out:
# /content/sampling_based_general

# %%
# !apt-get update
# !apt-get install -y libgl1-mesa-dev libegl1-mesa-dev

# %%
# !/content/py310_env/bin/pip install imageio[ffmpeg]

# %%
# !python3 -u real_demo/pendulum_demo_pyt_colab.py
# !/content/py310_env/bin/python3.10 real_demo/pendulum_demo_pyt_colab.py --num_batch 500 --maxiter_cem 1 --steps 100
# !/content/py310_env/bin/python3.10 \
    real_demo/walker_demo_pyt_colab.py \
    --num_batch 200 \
    --maxiter_cem 2 \
    --steps 10 \
    --timestep 0.05 \
    --maxiter_projection 5 \
    --num_steps 10
# Out:
# Sensors: 0 1 2
#
# Torque-controlled joints:
#   0: 'rootz' -> controlled: False
#   1: 'rootx' -> controlled: False
#   2: 'rooty' -> controlled: False
#   3: 'right_hip' -> controlled: True
#   4: 'right_knee' -> controlled: True
#   5: 'right_ankle' -> controlled: True
#   6: 'left_hip' -> controlled: True
#   7: 'left_knee' -> controlled: True
#   8: 'left_ankle' -> controlled: True
#
#  Default backend: gpu
#  Timestep: 0.05
#  CEM Iter: 2
#  Projection Iter: 5
#  Number of batches: 200
#  Number of steps per trajectory: 10
#  Time per trajectory: 0.5
#  Number of variables: 24
#  Number of Total constraints: 360
#
# Step 0
#
# Torso Position: [0.  0.  1.3]
#
# | Total time: 22.7s
# | Step time: 22671.8ms
# | Cost: 244.42
# | Height: 0.97
# | Orientation: 2.17
# | Velocity: 240.71
# | Control: 0.57
#
# Step 1
#
# Torso Position: [-0.      0.      1.2755]
#
# | Total time: 23.7s
# | Step time: 942.0ms
# | Cost: 188.95
# | Height: 0.75
# | Orientation: 1.38
# | Velocity: 185.94
# | Control: 0.89
#
# Step 2
#
# Torso Position: [-0.0093  0.      1.2825]
#
# | Total time: 24.1s
# | Step time: 425.5ms
# | Cost: 154.11
# | Height: 0.83
# | Orientation: 3.75
# | Velocity: 148.43
# | Control: 1.09
#
# Step 3
#
# Torso Position: [-0.0284  0.      1.2879]
#
# | Total time: 24.5s
# | Step time: 411.7ms
# | Cost: 126.56
# | Height: 0.75
# | Orientation: 0.72
# | Velocity: 124.29
# | Control: 0.79
#
# Step 4
#
# Torso Position: [-0.0447  0.      1.2535]
#
# | Total time: 24.9s
# | Step time: 408.7ms
# | Cost: 95.64
# | Height: 1.01
# | Orientation: 1.49
# | Velocity: 92.03
# | Control: 1.11
#
# Step 5
#
# Torso Position: [-0.0458  0.      1.2621]
#
# | Total time: 25.4s
# | Step time: 423.7ms
# | Cost: 74.34
# | Height: 1.44
# | Orientation: 1.59
# | Velocity: 70.35
# | Control: 0.95
#
# Step 6
#
# Torso Position: [-0.0406  0.      1.2659]
#
# | Total time: 25.8s
# | Step time: 413.4ms
# | Cost: 65.07
# | Height: 0.69
# | Orientation: 0.85
# | Velocity: 62.55
# | Control: 0.98
#
# Step 7
#
# Torso Position: [-0.0292  0.      1.2642]
#
# | Total time: 26.2s
# | Step time: 425.3ms
# | Cost: 47.68
# | Height: 0.68
# | Orientation: 0.67
# | Velocity: 45.53
# | Control: 0.81
#
# Step 8
#
# Torso Position: [-0.0088  0.      1.2643]
#
# | Total time: 26.6s
# | Step time: 415.7ms
# | Cost: 37.70
# | Height: 0.76
# | Orientation: 0.50
# | Velocity: 35.48
# | Control: 0.96
#
# Step 9
#
# Torso Position: [0.0208 0.     1.2639]
#
# | Total time: 27.1s
# | Step time: 415.0ms
# | Cost: 27.77
# | Height: 1.41
# | Orientation: 0.39
# | Velocity: 25.01
# | Control: 0.96
# /usr/lib/python3.10/subprocess.py:1796: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _posixsubprocess.fork_exec(
#
# Video saved: walker_video.mp4

# %%
from IPython.display import Video
Video("walker_video.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
