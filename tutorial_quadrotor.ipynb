# %% [markdown]
# <a href="https://colab.research.google.com/github/alinjar1996/tutorial_cem/blob/main/tutorial_quadrotor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get update
# !sudo apt-get install python3.10 python3.10-venv python3.10-distutils
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# !python3.10 -m venv py310_env

# %%
# !py310_env/bin/python -m ensurepip
# !py310_env/bin/pip install pip==22.0.2
# Out:
# Looking in links: /tmp/tmp37ptd3xx
# ...

# %%
# !py310_env/bin/python --version
# !py310_env/bin/pip --version
# Out:
# Python 3.10.12
# pip 22.0.2 from /content/sampling_based_general/real_demo/py310_env/lib/python3.10/site-packages/pip (python 3.10)

# %%
from google.colab import userdata

# Get the GitHub token from Colab secrets
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

# Clone the repository using the token
# !git clone https://{GITHUB_TOKEN}@github.com/alinjar1996/sampling_based_general.git -b issue_6_quadrotor_mpc
# Out:
# Cloning into 'sampling_based_general'...
# remote: Enumerating objects: 3974, done.
# remote: Counting objects: 100% (215/215), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 3974 (delta 123), reused 146 (delta 63), pack-reused 3759 (from 2)
# Receiving objects: 100% (3974/3974), 582.80 MiB | 19.67 MiB/s, done.
# Resolving deltas: 100% (1973/1973), done.
# Updating files: 100% (852/852), done.

# %%
# %cd /content/sampling_based_general
# !git pull
# Out:
# /content/sampling_based_general
# Already up to date.

# %%
# !ls /content
# !/content/py310_env/bin/pip install -r requirements.txt
# Out:
# math_utils  py310_env  sample_data  sampling_based_general
# ...

# %%
# %cd /content/sampling_based_general/real_demo

# !git clone https://github.com/AKS-Lab-Univertsity-of-Tartu/math_utils_aks_lab.git math_utils
# Out:
# /content/sampling_based_general/real_demo
# fatal: destination path 'math_utils' already exists and is not an empty directory.

# %%
# %cd /content/sampling_based_general
# Out:
# /content/sampling_based_general

# %%
# !apt-get update
# !apt-get install -y libgl1-mesa-dev libegl1-mesa-dev
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# !/content/py310_env/bin/pip install imageio[ffmpeg]

# %%
# !python3 -u real_demo/pendulum_demo_pyt_colab.py
# !/content/py310_env/bin/python3.10 real_demo/pendulum_demo_pyt_colab.py --num_batch 500 --maxiter_cem 1 --steps 100
# !/content/py310_env/bin/python3.10 \
    real_demo/real_demo/pyt_quadrotor_demo.py \
    --num_batch 50 \
    --maxiter_cem 40 \
    --num_steps 100 \
    --timestep 0.02 \
    --num_steps 50
# Out:
# ...
# Cost weights (default): {'height': 100.0, 'orientation': 50.0, 'nominal': 0.1}
# Traceback (most recent call last):
#   File "/content/sampling_based_general/real_demo/real_demo/pyt_quadrotor_demo.py", line 426, in <module>
#     main()
#   File "/content/sampling_based_general/real_demo/real_demo/pyt_quadrotor_demo.py", line 408, in main
#     planner = Planner(args)
#   File "/content/sampling_based_general/real_demo/real_demo/pyt_quadrotor_demo.py", line 195, in __init__
#     self.model = mujoco.MjModel.from_xml_path(MODEL_PATH)
# ValueError: Error: Error opening file '/content/sampling_based_general/real_demo/skydio_x2/X2_lowpoly_texture_SpinningProps_1024.png': No such file or directory

# %%
# !ls -l /content/sampling_based_general/real_demo/skydio_x2/

# %%
import re

# Read the original requirements.txt file
with open('/content/sampling_based_general/requirements.txt', 'r') as f:
    requirements = f.readlines()

# Filter out the problematic ipython line
new_requirements = [req for req in requirements if not re.match(r'^ipython==9\.2\.0', req.strip())]

# Write the modified requirements back to the file
with open('/content/sampling_based_general/requirements.txt', 'w') as f:
    f.writelines(new_requirements)

print('Modified requirements.txt to remove ipython==9.2.0.')
# Out:
# Modified requirements.txt to remove ipython==9.2.0.

# %%
# Re-install dependencies with the modified requirements.txt
# %cd /content/sampling_based_general
# !/content/py310_env/bin/pip install -r requirements.txt
# Out:
# /content/sampling_based_general
# ...

# %%
from IPython.display import Video
Video("walker_video.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="..._video.mp4" type="None">
#  Your browser does not support the video tag.
#  </video>
